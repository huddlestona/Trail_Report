# %%
import requests
import boto3
import pandas as pd

# %%
s3 = boto3.client('s3')

# %%
bucket_name = 'trailreportdata'
urls = ['https://www.ncei.noaa.gov/orders/cdo/1340157.csv','https://www.ncei.noaa.gov/orders/cdo/1340154.csv','https://www.ncei.noaa.gov/orders/cdo/1340149.csv','https://www.ncei.noaa.gov/orders/cdo/1340148.csv','https://www.ncei.noaa.gov/orders/cdo/1340144.csv','https://www.ncei.noaa.gov/orders/cdo/1340141.csv','https://www.ncei.noaa.gov/orders/cdo/1340136.csv','https://www.ncei.noaa.gov/orders/cdo/1340127.csv']

# %%
def get_past_weather_data(urls):
    for url in urls:
        response = requests.get(url)
        if response.status_code != 200:
            print(f"{response.status_code} scraping {url}")
        else:
            data = response.content
            filename = url.split("/")[-1]
            s3.put_object(Bucket= bucket_name, Body= data, Key= filename)
            print(f'{filename} downloaded')

# %%
get_past_weather_data(urls)
# Out:
# 1340157.csv downloaded
# 1340154.csv downloaded
# 1340149.csv downloaded
# 1340148.csv downloaded
# 1340144.csv downloaded
# 1340141.csv downloaded
# 1340136.csv downloaded
# 1340127.csv downloaded

# %%
pd.read_csv('s3:/trailreportdata/1340157.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/s3.py in <module>()
#       3 try:
# ----> 4     import s3fs
#       5     from botocore.exceptions import NoCredentialsError
#
# ModuleNotFoundError: No module named 's3fs'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-86ba9468018f> in <module>()
# ----> 1 pd.read_csv('s3:/trailreportdata/1340157.csv')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     431     compression = _infer_compression(filepath_or_buffer, compression)
#     432     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 433         filepath_or_buffer, encoding, compression)
#     434     kwds['compression'] = compression
#     435
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     197
#     198     if _is_s3_url(filepath_or_buffer):
# --> 199         from pandas.io import s3
#     200         return s3.get_filepath_or_buffer(filepath_or_buffer,
#     201                                          encoding=encoding,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/s3.py in <module>()
#       5     from botocore.exceptions import NoCredentialsError
#       6 except:
# ----> 7     raise ImportError("The s3fs library is required to handle s3 files")
#       8
#       9 if compat.PY3:
#
# ImportError: The s3fs library is required to handle s3 files

# %%
ad.csv(text = rawToChar(get_object(object = "1340157.csv", bucket = bucket_name)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0610d205a890> in <module>()
# ----> 1 read.csv(text = rawToChar(get_object(object = "1340157.csv", bucket = bucket_name)))
#
# NameError: name 'read' is not defined

# %%
pd.read_csv('http://s3-aws-region.amazonaws.com/bucket')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9b151c7b3906> in <module>()
# ----> 1 warnings.warn('test')
#
# NameError: name 'warnings' is not defined

# %%
df = pd.read_csv('../weather_data/1340148.csv')

# %%
df
# Out:
#            STATION                    NAME        DATE  AWND  DAPR  FMTM  \
# 0      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-05   NaN   NaN   NaN
# 1      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-06   NaN   NaN   NaN
# 2      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-07   NaN   NaN   NaN
# 3      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-08   NaN   NaN   NaN
# 4      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-09   NaN   NaN   NaN
# 5      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-10   NaN   NaN   NaN
# 6      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-11   NaN   NaN   NaN
# 7      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-12   NaN   NaN   NaN
# 8      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-13   NaN   NaN   NaN
# 9      US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-14   NaN   NaN   NaN
# 10     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-15   NaN   NaN   NaN
# 11     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-16   NaN   NaN   NaN
# 12     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-17   NaN   NaN   NaN
# 13     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-18   NaN   NaN   NaN
# 14     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-19   NaN   NaN   NaN
# 15     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-20   NaN   NaN   NaN
# 16     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-21   NaN   NaN   NaN
# 17     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-22   NaN   NaN   NaN
# 18     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-23   NaN   NaN   NaN
# 19     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-01-24   NaN   NaN   NaN
# 20     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-01   NaN   NaN   NaN
# 21     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-02   NaN   NaN   NaN
# 22     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-03   NaN   NaN   NaN
# 23     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-04   NaN   NaN   NaN
# 24     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-05   NaN   NaN   NaN
# 25     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-06   NaN   NaN   NaN
# 26     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-07   NaN   NaN   NaN
# 27     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-08   NaN   NaN   NaN
# 28     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-09   NaN   NaN   NaN
# 29     US1WAGH0041  HOQUIAM 0.3 NNW, WA US  2015-02-10   NaN   NaN   NaN
# ...            ...                     ...         ...   ...   ...   ...
# 71078  USC00452531             ELMA, WA US  2016-12-02   NaN   NaN   NaN
# 71079  USC00452531             ELMA, WA US  2016-12-03   NaN   NaN   NaN
# 71080  USC00452531             ELMA, WA US  2016-12-04   NaN   NaN   NaN
# 71081  USC00452531             ELMA, WA US  2016-12-05   NaN   NaN   NaN
# 71082  USC00452531             ELMA, WA US  2016-12-06   NaN   NaN   NaN
# 71083  USC00452531             ELMA, WA US  2016-12-07   NaN   NaN   NaN
# 71084  USC00452531             ELMA, WA US  2016-12-08   NaN   NaN   NaN
# 71085  USC00452531             ELMA, WA US  2016-12-09   NaN   NaN   NaN
# 71086  USC00452531             ELMA, WA US  2016-12-10   NaN   NaN   NaN
# 71087  USC00452531             ELMA, WA US  2016-12-11   NaN   NaN   NaN
# 71088  USC00452531             ELMA, WA US  2016-12-12   NaN   NaN   NaN
# 71089  USC00452531             ELMA, WA US  2016-12-13   NaN   NaN   NaN
# 71090  USC00452531             ELMA, WA US  2016-12-14   NaN   NaN   NaN
# 71091  USC00452531             ELMA, WA US  2016-12-15   NaN   NaN   NaN
# 71092  USC00452531             ELMA, WA US  2016-12-16   NaN   NaN   NaN
# 71093  USC00452531             ELMA, WA US  2016-12-17   NaN   NaN   NaN
# 71094  USC00452531             ELMA, WA US  2016-12-18   NaN   NaN   NaN
# 71095  USC00452531             ELMA, WA US  2016-12-19   NaN   NaN   NaN
# 71096  USC00452531             ELMA, WA US  2016-12-20   NaN   NaN   NaN
# 71097  USC00452531             ELMA, WA US  2016-12-21   NaN   NaN   NaN
# 71098  USC00452531             ELMA, WA US  2016-12-22   NaN   NaN   NaN
# 71099  USC00452531             ELMA, WA US  2016-12-23   NaN   NaN   NaN
# 71100  USC00452531             ELMA, WA US  2016-12-24   NaN   NaN   NaN
# 71101  USC00452531             ELMA, WA US  2016-12-25   NaN   NaN   NaN
# 71102  USC00452531             ELMA, WA US  2016-12-26   NaN   NaN   NaN
# 71103  USC00452531             ELMA, WA US  2016-12-27   NaN   NaN   NaN
# 71104  USC00452531             ELMA, WA US  2016-12-28   NaN   NaN   NaN
# 71105  USC00452531             ELMA, WA US  2016-12-29   NaN   NaN   NaN
# 71106  USC00452531             ELMA, WA US  2016-12-30   NaN   NaN   NaN
# 71107  USC00452531             ELMA, WA US  2016-12-31   NaN   NaN   NaN
#
#        MDPR  PGTM  PRCP  SNOW  ...   WT08  WT09  WT11  WT13  WT16  WT17  WT18  \
# 0       NaN   NaN  8.14   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN  0.07   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5       NaN   NaN  0.07   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6       NaN   NaN  0.03   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7       NaN   NaN  0.02   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8       NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9       NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10      NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11      NaN   NaN  0.52   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12      NaN   NaN  0.03   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13      NaN   NaN  1.63   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14      NaN   NaN  0.28   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15      NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 16      NaN   NaN  0.00   0.0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17      NaN   NaN  0.14   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 18      NaN   NaN  0.09   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 19      NaN   NaN  1.20   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 20      NaN   NaN  0.07   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 21      NaN   NaN  0.41   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 22      NaN   NaN  0.42   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23      NaN   NaN  0.13   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 24      NaN   NaN  0.75   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25      NaN   NaN  1.61   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 26      NaN   NaN  0.90   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 27      NaN   NaN  0.43   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 28      NaN   NaN  0.57   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 29      NaN   NaN  0.30   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...  ...    ...   ...   ...   ...   ...   ...   ...
# 71078   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71079   NaN   NaN  0.59   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71080   NaN   NaN  0.67   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71081   NaN   NaN  0.37   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71082   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71083   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71084   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71085   NaN   NaN  0.60   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71086   NaN   NaN  0.58   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71087   NaN   NaN  0.81   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71088   NaN   NaN  0.65   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71089   NaN   NaN  0.06   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71090   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71091   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71092   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71093   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71094   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71095   NaN   NaN  1.01   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71096   NaN   NaN  1.21   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71097   NaN   NaN  0.01   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71098   NaN   NaN  0.16   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71099   NaN   NaN  1.01   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71100   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71101   NaN   NaN  0.00   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71102   NaN   NaN  0.11   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71103   NaN   NaN  0.88   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71104   NaN   NaN  0.12   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71105   NaN   NaN  0.20   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71106   NaN   NaN  0.20   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 71107   NaN   NaN  0.10   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        WT19  WT22  WV03
# 0       NaN   NaN   NaN
# 1       NaN   NaN   NaN
# 2       NaN   NaN   NaN
# 3       NaN   NaN   NaN
# 4       NaN   NaN   NaN
# 5       NaN   NaN   NaN
# 6       NaN   NaN   NaN
# 7       NaN   NaN   NaN
# 8       NaN   NaN   NaN
# 9       NaN   NaN   NaN
# 10      NaN   NaN   NaN
# 11      NaN   NaN   NaN
# 12      NaN   NaN   NaN
# 13      NaN   NaN   NaN
# 14      NaN   NaN   NaN
# 15      NaN   NaN   NaN
# 16      NaN   NaN   NaN
# 17      NaN   NaN   NaN
# 18      NaN   NaN   NaN
# 19      NaN   NaN   NaN
# 20      NaN   NaN   NaN
# 21      NaN   NaN   NaN
# 22      NaN   NaN   NaN
# 23      NaN   NaN   NaN
# 24      NaN   NaN   NaN
# 25      NaN   NaN   NaN
# 26      NaN   NaN   NaN
# 27      NaN   NaN   NaN
# 28      NaN   NaN   NaN
# 29      NaN   NaN   NaN
# ...     ...   ...   ...
# 71078   NaN   NaN   NaN
# 71079   NaN   NaN   NaN
# 71080   NaN   NaN   NaN
# 71081   NaN   NaN   NaN
# 71082   NaN   NaN   NaN
# 71083   NaN   NaN   NaN
# 71084   NaN   NaN   NaN
# 71085   NaN   NaN   NaN
# 71086   NaN   NaN   NaN
# 71087   NaN   NaN   NaN
# 71088   NaN   NaN   NaN
# 71089   NaN   NaN   NaN
# 71090   NaN   NaN   NaN
# 71091   NaN   NaN   NaN
# 71092   NaN   NaN   NaN
# 71093   NaN   NaN   NaN
# 71094   NaN   NaN   NaN
# 71095   NaN   NaN   NaN
# 71096   NaN   NaN   NaN
# 71097   NaN   NaN   NaN
# 71098   NaN   NaN   NaN
# 71099   NaN   NaN   NaN
# 71100   NaN   NaN   NaN
# 71101   NaN   NaN   NaN
# 71102   NaN   NaN   NaN
# 71103   NaN   NaN   NaN
# 71104   NaN   NaN   NaN
# 71105   NaN   NaN   NaN
# 71106   NaN   NaN   NaN
# 71107   NaN   NaN   NaN
#
# [71108 rows x 39 columns]

# %%
len(df['STATION'].unique())
# Out:
# 39

# %%
df['NAME'].unique()
# Out:
# array(['HOQUIAM 0.3 NNW, WA US', 'ABERDEEN 6.1 E, WA US',
#        'MONTESANO 2.8 SW, WA US', 'OAKVILLE, WA US',
#        'OCEAN SHORES 0.5 WSW, WA US', 'OCEAN CITY 1.1 SSE, WA US',
#        'MONTESANO 4.2 ESE, WA US', 'MONTESANO 4.5 SW, WA US',
#        'QUINAULT 2.2 NE, WA US', 'BLACK KNOB WASHINGTON, WA US',
#        'OCEAN SHORES 2.6 N, WA US', 'ABERDEEN, WA US',
#        'OCEAN SHORES 1.2 N, WA US', 'ABERDEEN 5.9 E, WA US',
#        'OAKVILLE 7.8 NW, WA US', 'ELMA 16.0 NNW, WA US',
#        'ABERDEEN 1.6 WSW, WA US', 'ABERDEEN 0.9 S, WA US',
#        'HOQUIAM 6.7 NNW, WA US', 'COPALIS CROSSING 2.1 NNW, WA US',
#        'OCEAN SHORES 0.6 ENE, WA US', 'QUINAULT 4 NE, WA US',
#        'ABERDEEN 0.7 WSW, WA US', 'OCEAN SHORES 1.2 S, WA US',
#        'OCEAN SHORES 0.9 SSE, WA US', 'MONTESANO 2.3 SSW, WA US',
#        'OCEAN SHORES 1.2 NNW, WA US', 'ABERDEEN 2.1 SE, WA US',
#        'HUMPTULIPS SALMON HATCHERY, WA US', 'COSMOPOLIS 6.0 SE, WA US',
#        'GRAYLAND, WA US', 'ELMA 0.5 W, WA US', 'MONTESANO 4.2 NW, WA US',
#        'HOQUIAM BOWERMAN AIRPORT, WA US', 'MONTESANO 2.1 SSW, WA US',
#        'MONTESANO 5.8 WNW, WA US', 'OCEAN SHORES 2.8 N, WA US',
#        'ABERDEEN 20 NNE, WA US', 'ELMA, WA US'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71108 entries, 0 to 71107
# Data columns (total 39 columns):
# STATION    71108 non-null object
# NAME       71108 non-null object
# DATE       71108 non-null object
# AWND       5771 non-null float64
# DAPR       14 non-null float64
# FMTM       4383 non-null float64
# MDPR       42 non-null float64
# PGTM       4219 non-null float64
# PRCP       65869 non-null float64
# SNOW       33948 non-null float64
# SNWD       25347 non-null float64
# TAVG       6625 non-null float64
# TMAX       44257 non-null float64
# TMIN       43664 non-null float64
# TOBS       28013 non-null float64
# TSUN       1127 non-null float64
# WDF2       5770 non-null float64
# WDF5       5764 non-null float64
# WESD       389 non-null float64
# WESF       491 non-null float64
# WSF2       5770 non-null float64
# WSF5       5764 non-null float64
# WT01       4177 non-null float64
# WT02       558 non-null float64
# WT03       91 non-null float64
# WT04       62 non-null float64
# WT05       620 non-null float64
# WT06       21 non-null float64
# WT07       41 non-null float64
# WT08       592 non-null float64
# WT09       75 non-null float64
# WT11       20 non-null float64
# WT13       2938 non-null float64
# WT16       2634 non-null float64
# WT17       50 non-null float64
# WT18       111 non-null float64
# WT19       63 non-null float64
# WT22       37 non-null float64
# WV03       22 non-null float64
# dtypes: float64(36), object(3)
# memory usage: 21.2+ MB

# %%
df['DATE'].unique()
# Out:
# array(['2015-01-05', '2015-01-06', '2015-01-07', ..., '2000-02-27',
#        '2000-02-28', '2000-02-29'], dtype=object)

# %%
df2 = pd.read_csv('../weather_data/1340157.csv')

# %%
df2
# Out:
#          STATION                            NAME  LATITUDE  LONGITUDE  \
# 0    US1WAGH0010          HOQUIAM 6.7 NNW, WA US   47.0667  -123.9321
# 1    US1WAGH0031     OCEAN SHORES 0.6 ENE, WA US   46.9736  -124.1406
# 2    US1WAGH0031     OCEAN SHORES 0.6 ENE, WA US   46.9736  -124.1406
# 3    US1WAGH0031     OCEAN SHORES 0.6 ENE, WA US   46.9736  -124.1406
# 4    US1WAGH0031     OCEAN SHORES 0.6 ENE, WA US   46.9736  -124.1406
# 5    US1WAGH0031     OCEAN SHORES 0.6 ENE, WA US   46.9736  -124.1406
# 6    USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 7    USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 8    USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 9    USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 10   USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 11   USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 12   USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 13   USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 14   USW00004237            QUINAULT 4 NE, WA US   47.5139  -123.8120
# 15   US1WAGH0033     OCEAN SHORES 0.9 SSE, WA US   46.9583  -124.1477
# 16   US1WAGH0033     OCEAN SHORES 0.9 SSE, WA US   46.9583  -124.1477
# 17   US1WAGH0033     OCEAN SHORES 0.9 SSE, WA US   46.9583  -124.1477
# 18   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 19   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 20   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 21   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 22   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 23   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 24   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 25   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 26   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 27   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 28   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# 29   USC00455086              MATLOCK 8 S, WA US   47.1455  -123.4005
# ..           ...                             ...       ...        ...
# 171  USW00094227  SHELTON SANDERSON FIELD, WA US   47.2380  -123.1408
# 172  USW00094227  SHELTON SANDERSON FIELD, WA US   47.2380  -123.1408
# 173  USW00094227  SHELTON SANDERSON FIELD, WA US   47.2380  -123.1408
# 174  USW00094227  SHELTON SANDERSON FIELD, WA US   47.2380  -123.1408
# 175  US1WAGH0019         ABERDEEN 1.6 WSW, WA US   46.9721  -123.8407
# 176  USC00450013          ABERDEEN 20 NNE, WA US   47.2613  -123.7147
# 177  USC00450013          ABERDEEN 20 NNE, WA US   47.2613  -123.7147
# 178  USC00450013          ABERDEEN 20 NNE, WA US   47.2613  -123.7147
# 179  USC00450013          ABERDEEN 20 NNE, WA US   47.2613  -123.7147
# 180  USC00450013          ABERDEEN 20 NNE, WA US   47.2613  -123.7147
# 181  USC00450013          ABERDEEN 20 NNE, WA US   47.2613  -123.7147
# 182  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 183  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 184  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 185  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 186  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 187  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 188  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 189  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 190  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 191  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 192  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 193  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 194  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 195  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 196  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 197  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 198  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 199  USC00452531                     ELMA, WA US   47.0091  -123.4008
# 200  USC00452531                     ELMA, WA US   47.0091  -123.4008
#
#      ELEVATION  DATE  AWND AWND_ATTRIBUTES   CDSD  CDSD_ATTRIBUTES  \
# 0         11.9  2009   NaN             NaN    NaN              NaN
# 1          7.3  2012   NaN             NaN    NaN              NaN
# 2          7.3  2013   NaN             NaN    NaN              NaN
# 3          7.3  2014   NaN             NaN    NaN              NaN
# 4          7.3  2015   NaN             NaN    NaN              NaN
# 5          7.3  2016   NaN             NaN    NaN              NaN
# 6         87.2  2008   NaN             NaN   47.0              NaN
# 7         87.2  2009   NaN             NaN  118.0              NaN
# 8         87.2  2010   NaN             NaN   59.0              NaN
# 9         87.2  2011   NaN             NaN   28.0              NaN
# 10        87.2  2013   NaN             NaN   51.0              NaN
# 11        87.2  2014   NaN             NaN  135.0              NaN
# 12        87.2  2015   NaN             NaN  182.0              NaN
# 13        87.2  2016   NaN             NaN  110.0              NaN
# 14        87.2  2017   NaN             NaN  168.0              NaN
# 15         0.0  2014   NaN             NaN    NaN              NaN
# 16         0.0  2016   NaN             NaN    NaN              NaN
# 17         0.0  2017   NaN             NaN    NaN              NaN
# 18        33.5  1997   NaN             NaN    NaN              NaN
# 19        33.5  1998   NaN             NaN    NaN              NaN
# 20        33.5  1999   NaN             NaN    NaN              NaN
# 21        33.5  2000   NaN             NaN    NaN              NaN
# 22        33.5  2001   NaN             NaN    NaN              NaN
# 23        33.5  2002   NaN             NaN    NaN              NaN
# 24        33.5  2003   NaN             NaN    NaN              NaN
# 25        33.5  2004   NaN             NaN    NaN              NaN
# 26        33.5  2005   NaN             NaN    NaN              NaN
# 27        33.5  2006   NaN             NaN    NaN              NaN
# 28        33.5  2007   NaN             NaN    NaN              NaN
# 29        33.5  2008   NaN             NaN    NaN              NaN
# ..         ...   ...   ...             ...    ...              ...
# 171       82.6  2014   6.3               W  184.0              NaN
# 172       82.6  2015   5.8               W  250.0              NaN
# 173       82.6  2016   6.0               W  169.0              NaN
# 174       82.6  2017   5.8               W  225.0              NaN
# 175        4.3  2017   NaN             NaN    NaN              NaN
# 176      132.6  1997   NaN             NaN   29.0              NaN
# 177      132.6  1998   NaN             NaN   79.0              NaN
# 178      132.6  1999   NaN             NaN   10.0              NaN
# 179      132.6  2000   NaN             NaN    NaN              NaN
# 180      132.6  2002   NaN             NaN    NaN              NaN
# 181      132.6  2003   NaN             NaN    NaN              NaN
# 182       21.3  1997   NaN             NaN    NaN              NaN
# 183       21.3  1998   NaN             NaN    NaN              NaN
# 184       21.3  1999   NaN             NaN    NaN              NaN
# 185       21.3  2001   NaN             NaN    NaN              NaN
# 186       21.3  2002   NaN             NaN    NaN              NaN
# 187       21.3  2003   NaN             NaN    NaN              NaN
# 188       21.3  2004   NaN             NaN    NaN              NaN
# 189       21.3  2005   NaN             NaN    NaN              NaN
# 190       21.3  2006   NaN             NaN  157.0              NaN
# 191       21.3  2007   NaN             NaN  132.0              NaN
# 192       21.3  2008   NaN             NaN  174.0              NaN
# 193       21.3  2010   NaN             NaN  145.0              NaN
# 194       21.3  2011   NaN             NaN  113.0              NaN
# 195       21.3  2012   NaN             NaN  127.0              NaN
# 196       21.3  2013   NaN             NaN  167.0              NaN
# 197       21.3  2014   NaN             NaN  270.0              NaN
# 198       21.3  2015   NaN             NaN  313.0              NaN
# 199       21.3  2016   NaN             NaN  204.0              NaN
# 200       21.3  2017   NaN             NaN  290.0              NaN
#
#           ...        TMIN TMIN_ATTRIBUTES   WDF2 WDF2_ATTRIBUTES   WDF5  \
# 0         ...         NaN             NaN    NaN             NaN    NaN
# 1         ...         NaN             NaN    NaN             NaN    NaN
# 2         ...         NaN             NaN    NaN             NaN    NaN
# 3         ...         NaN             NaN    NaN             NaN    NaN
# 4         ...         NaN             NaN    NaN             NaN    NaN
# 5         ...         NaN             NaN    NaN             NaN    NaN
# 6         ...        40.2               R    NaN             NaN    NaN
# 7         ...        40.5               R    NaN             NaN    NaN
# 8         ...        42.4               R    NaN             NaN    NaN
# 9         ...        40.6               R    NaN             NaN    NaN
# 10        ...        42.0               R    NaN             NaN    NaN
# 11        ...        43.7               R    NaN             NaN    NaN
# 12        ...        43.9               R    NaN             NaN    NaN
# 13        ...        44.0               R    NaN             NaN    NaN
# 14        ...        41.8               R    NaN             NaN    NaN
# 15        ...         NaN             NaN    NaN             NaN    NaN
# 16        ...         NaN             NaN    NaN             NaN    NaN
# 17        ...         NaN             NaN    NaN             NaN    NaN
# 18        ...         NaN             NaN    NaN             NaN    NaN
# 19        ...         NaN             NaN    NaN             NaN    NaN
# 20        ...         NaN             NaN    NaN             NaN    NaN
# 21        ...         NaN             NaN    NaN             NaN    NaN
# 22        ...         NaN             NaN    NaN             NaN    NaN
# 23        ...         NaN             NaN    NaN             NaN    NaN
# 24        ...         NaN             NaN    NaN             NaN    NaN
# 25        ...         NaN             NaN    NaN             NaN    NaN
# 26        ...         NaN             NaN    NaN             NaN    NaN
# 27        ...         NaN             NaN    NaN             NaN    NaN
# 28        ...         NaN             NaN    NaN             NaN    NaN
# 29        ...         NaN             NaN    NaN             NaN    NaN
# ..        ...         ...             ...    ...             ...    ...
# 171       ...        42.1               W  220.0               W  240.0
# 172       ...        42.0               W  230.0               W  240.0
# 173       ...        42.6               W  210.0               W  210.0
# 174       ...        40.9               W  210.0               W  210.0
# 175       ...         NaN             NaN    NaN             NaN    NaN
# 176       ...        42.3               0    NaN             NaN    NaN
# 177       ...        42.6               0    NaN             NaN    NaN
# 178       ...        40.9               0    NaN             NaN    NaN
# 179       ...         NaN             NaN    NaN             NaN    NaN
# 180       ...         NaN             NaN    NaN             NaN    NaN
# 181       ...         NaN             NaN    NaN             NaN    NaN
# 182       ...        41.9               0    NaN             NaN    NaN
# 183       ...        42.6               0    NaN             NaN    NaN
# 184       ...        40.9               0    NaN             NaN    NaN
# 185       ...        40.2               0    NaN             NaN    NaN
# 186       ...        40.3               0    NaN             NaN    NaN
# 187       ...        41.9               0    NaN             NaN    NaN
# 188       ...        42.3               0    NaN             NaN    NaN
# 189       ...        41.4               0    NaN             NaN    NaN
# 190       ...        40.7               0    NaN             NaN    NaN
# 191       ...        42.0               0    NaN             NaN    NaN
# 192       ...        41.3               0    NaN             NaN    NaN
# 193       ...        42.9               0    NaN             NaN    NaN
# 194       ...        40.8               7    NaN             NaN    NaN
# 195       ...        41.0               7    NaN             NaN    NaN
# 196       ...        41.9               7    NaN             NaN    NaN
# 197       ...        43.0               7    NaN             NaN    NaN
# 198       ...        42.8               7    NaN             NaN    NaN
# 199       ...        43.0               7    NaN             NaN    NaN
# 200       ...        41.1               7    NaN             NaN    NaN
#
#     WDF5_ATTRIBUTES  WSF2  WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES
# 0               NaN   NaN              NaN   NaN             NaN
# 1               NaN   NaN              NaN   NaN             NaN
# 2               NaN   NaN              NaN   NaN             NaN
# 3               NaN   NaN              NaN   NaN             NaN
# 4               NaN   NaN              NaN   NaN             NaN
# 5               NaN   NaN              NaN   NaN             NaN
# 6               NaN   NaN              NaN   NaN             NaN
# 7               NaN   NaN              NaN   NaN             NaN
# 8               NaN   NaN              NaN   NaN             NaN
# 9               NaN   NaN              NaN   NaN             NaN
# 10              NaN   NaN              NaN   NaN             NaN
# 11              NaN   NaN              NaN   NaN             NaN
# 12              NaN   NaN              NaN   NaN             NaN
# 13              NaN   NaN              NaN   NaN             NaN
# 14              NaN   NaN              NaN   NaN             NaN
# 15              NaN   NaN              NaN   NaN             NaN
# 16              NaN   NaN              NaN   NaN             NaN
# 17              NaN   NaN              NaN   NaN             NaN
# 18              NaN   NaN              NaN   NaN             NaN
# 19              NaN   NaN              NaN   NaN             NaN
# 20              NaN   NaN              NaN   NaN             NaN
# 21              NaN   NaN              NaN   NaN             NaN
# 22              NaN   NaN              NaN   NaN             NaN
# 23              NaN   NaN              NaN   NaN             NaN
# 24              NaN   NaN              NaN   NaN             NaN
# 25              NaN   NaN              NaN   NaN             NaN
# 26              NaN   NaN              NaN   NaN             NaN
# 27              NaN   NaN              NaN   NaN             NaN
# 28              NaN   NaN              NaN   NaN             NaN
# 29              NaN   NaN              NaN   NaN             NaN
# ..              ...   ...              ...   ...             ...
# 171               W  36.9                W  51.0               W
# 172               W  36.9                W  55.9               W
# 173               W  45.0                W  66.0               W
# 174               W  33.1                W  47.0               W
# 175             NaN   NaN              NaN   NaN             NaN
# 176             NaN   NaN              NaN   NaN             NaN
# 177             NaN   NaN              NaN   NaN             NaN
# 178             NaN   NaN              NaN   NaN             NaN
# 179             NaN   NaN              NaN   NaN             NaN
# 180             NaN   NaN              NaN   NaN             NaN
# 181             NaN   NaN              NaN   NaN             NaN
# 182             NaN   NaN              NaN   NaN             NaN
# 183             NaN   NaN              NaN   NaN             NaN
# 184             NaN   NaN              NaN   NaN             NaN
# 185             NaN   NaN              NaN   NaN             NaN
# 186             NaN   NaN              NaN   NaN             NaN
# 187             NaN   NaN              NaN   NaN             NaN
# 188             NaN   NaN              NaN   NaN             NaN
# 189             NaN   NaN              NaN   NaN             NaN
# 190             NaN   NaN              NaN   NaN             NaN
# 191             NaN   NaN              NaN   NaN             NaN
# 192             NaN   NaN              NaN   NaN             NaN
# 193             NaN   NaN              NaN   NaN             NaN
# 194             NaN   NaN              NaN   NaN             NaN
# 195             NaN   NaN              NaN   NaN             NaN
# 196             NaN   NaN              NaN   NaN             NaN
# 197             NaN   NaN              NaN   NaN             NaN
# 198             NaN   NaN              NaN   NaN             NaN
# 199             NaN   NaN              NaN   NaN             NaN
# 200             NaN   NaN              NaN   NaN             NaN
#
# [201 rows x 82 columns]

# %%
df_all = pd.read_csv('data/WTA_olympics_allmerged.csv', sep = '|', lineterminator='\n')

# %%
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(df_all['lat'])
lon1 = radians(df_all['long'])
lat2 = radians(df2['LATITUDE'])
lon2 = radians(df2['LONGITUDE'])

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c
