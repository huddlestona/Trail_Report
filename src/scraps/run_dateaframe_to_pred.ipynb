# %%
from make_dataframe import *
import pandas as pd

# %%
    df = pd.read_csv('../data/olympics_merged.csv', sep = '|',lineterminator='\n')
    df_clean = add_knn(df)
    df_merge = merge_all_files(df_clean)
    df_final = clean_X(df_merge)
    train_X,train_y = split_x_y(df_final)

# %%
from make_all_predictions import *

# %%
tp = TrailPred()

# %%
tp.fit()

# %%
tp.X_train is train_X
# Out:
# False

# %%
for col in tp.X_train.columns:
    if col not in train_X.columns:
        print(col)

# %%
len(tp.X_train.columns)
# Out:
# 140

# %%
len(train_X.columns)
# Out:
# 140

# %%
from knn_model import make_forest

# %%
snow_fit = make_forest(train_X,train_y['condition|snow'])

# %%
conditions = ['condition|snow', 'condition|trail','condition|bugs','condition|road']
conditions_fit = {}
for condition in conditions:
    fit = make_forest(train_X,train_y[condition])
    conditions_fit[condition]= fit

# %%
    hike = 'Mount Rose'
    date = '2018-05-06'
    X_test = get_data(hike,date)
# Out:
# /Users/ashley/projects/Trail_Report/src/make_all_predictions.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df[f'neighbors_average {condition}'] = get_new_neighbors(df,condition,hike,date_stamp)
# /Users/ashley/projects/Trail_Report/src/make_all_predictions.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['date'] = date_stamp
# /Users/ashley/projects/Trail_Report/src/make_all_predictions.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
conditions_fit
# Out:
# {'condition|bugs': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'condition|road': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
# ...

# %%
train_X
# Out:
#        date_sin  date_cos  Coast  Dogs not allowed  Established campsites  \
# 0     -0.714876  0.699251      0                 0                      0
# 1     -0.714876  0.699251      0                 0                      0
# 2     -0.714876  0.699251      0                 0                      0
# 3      0.580611  0.814181      0                 0                      0
# 4      0.580611  0.814181      0                 0                      0
# 5      0.580611  0.814181      0                 0                      0
# 6      0.580611  0.814181      0                 0                      0
# 7      0.580611  0.814181      0                 0                      0
# 8      0.580611  0.814181      0                 0                      0
# 9      0.580611  0.814181      0                 0                      0
# 10     0.580611  0.814181      0                 0                      0
# 11     0.580611  0.814181      0                 0                      0
# ...

# %%
snow_fit.predict_proba(X_test)
# Out:
# array([[ 0.70666667,  0.29333333]])

# %%
road_fit = conditions_fit['condition|road']

# %%
trail_fit = conditions_fit['condition|trail']

# %%
bug_fit = conditions_fit['condition|bugs']

# %%
feature_values = {}
for i in range(len(bug_fit.feature_importances_)):
   feature_values[X_test.columns[i]] = bug_fit.feature_importances_[i]

top_features = sorted(feature_values.items(), key=lambda x: x[1], reverse=True)
top_features
# Out:
# [('date_sin', 0.35808637616251482),
#  ('neighbors_average condition|road', 0.087538947421544638),
#  ('Coast', 0.067126333962400919),
#  ('date_cos', 0.065006868124960746),
#  ('Dogs not allowed', 0.063225957842277136),
#  ('neighbors_average condition|bugs', 0.060963300278885475),
#  ('long', 0.019416483686877747),
#  ('Backcountry camping permit. Register in person at ranger station (no fee)',
#   0.018600338214749695),
#  ('lat', 0.018502513668922346),
#  ('station_distance', 0.016390186362430254),
#  ('total_distance', 0.015168966743797609),
#  ('Discover Pass', 0.015157626570014361),
#  ('neighbors_average condition|trail', 0.014364649350374856),
#  ('number_votes', 0.014264891446934545),
#  ('stars', 0.013262685259782169),
#  ('numReports', 0.012573287065090553),
#  ('Old growth', 0.0068305575489798218),
#  ('DP01', 0.0048938635409154791),
#  ('Fall foilage', 0.0048870663747571713),
#  ('EMXP', 0.0045546405504642024),
#  ('DP10', 0.0044666946694476243),
# ...

# %%
feature_values = {}
for i in range(len(road_fit.feature_importances_)):
   feature_values[X_test.columns[i]] = road_fit.feature_importances_[i]

top_features = sorted(feature_values.items(), key=lambda x: x[1], reverse=True)
top_features
# Out:
# [('date_cos', 0.30279639937081571),
#  ('neighbors_average condition|road', 0.083515136338067397),
#  ('neighbors_average condition|bugs', 0.076305527521587604),
#  ('Coast', 0.06329978354036668),
#  ('Dogs not allowed', 0.061771195699954824),
#  ('date_sin', 0.031597647640925666),
#  ('number_votes', 0.024321974295897664),
#  ('numReports', 0.022822742512952566),
#  ('neighbors_average condition|trail', 0.022431850184916103),
#  ('long', 0.021874187953730927),
#  ('station_distance', 0.020437996737952904),
#  ('lat', 0.01781437248951499),
#  ('total_distance', 0.017312915099733119),
#  ('Discover Pass', 0.016171433149256991),
#  ('Backcountry camping permit. Register in person at ranger station (no fee)',
#   0.01606609563285389),
#  ('stars', 0.015975896502961197),
#  (' Leavenworth Area', 0.008025745069915562),
#  ('DP01', 0.0079301534697790339),
#  ('CDSD', 0.0070995572429113449),
#  ('PRCP', 0.0068777262499468373),
#  ('DP10', 0.0062529897689351669),
# ...

# %%
feature_values = {}
for i in range(len(trail_fit.feature_importances_)):
   feature_values[X_test.columns[i]] = trail_fit.feature_importances_[i]

top_features = sorted(feature_values.items(), key=lambda x: x[1], reverse=True)
top_features
# Out:
# [('neighbors_average condition|road', 0.3324957109171216),
#  ('Dogs not allowed', 0.065397154700797114),
#  ('neighbors_average condition|bugs', 0.064831937279059088),
#  ('Coast', 0.06412918321816484),
#  ('date_cos', 0.058947976752582162),
#  ('date_sin', 0.03386435050895583),
#  ('station_distance', 0.024292762625992816),
#  ('long', 0.023869501314872647),
#  ('Backcountry camping permit. Register in person at ranger station (no fee)',
#   0.022717419914716167),
#  ('number_votes', 0.022026791906838226),
#  ('numReports', 0.018971866512248397),
#  ('lat', 0.018781593190852978),
#  ('neighbors_average condition|trail', 0.018076766954281332),
#  ('total_distance', 0.016746192220593269),
#  ('stars', 0.016314150268375707),
#  ('Discover Pass', 0.01630788280125298),
#  ('DP01', 0.008969546017352243),
#  ('EMXP', 0.0074044589216908522),
#  ('Waterfalls', 0.007242235466612363),
#  ('DP10', 0.0071552202772425418),
#  ('PRCP', 0.0071107501731091987),
#  ('DX70', 0.0052170042137149632),
# ...

# %%
feature_values = {}
for i in range(len(snow_fit.feature_importances_)):
   feature_values[X_test.columns[i]] = snow_fit.feature_importances_[i]

top_features = sorted(feature_values.items(), key=lambda x: x[1], reverse=True)
top_features
# Out:
# [('neighbors_average condition|bugs', 0.27817100407389711),
#  ('neighbors_average condition|road', 0.077067025596045155),
#  ('date_cos', 0.065543499408046116),
#  ('Dogs not allowed', 0.056502220282633978),
#  ('Coast', 0.056199096504432583),
#  ('long', 0.032330816206346993),
#  ('date_sin', 0.029604865070861477),
#  ('lat', 0.026998342482826319),
#  ('station_distance', 0.018326573824451367),
#  ('total_distance', 0.017944743641917737),
#  ('Backcountry camping permit. Register in person at ranger station (no fee)',
#   0.017408380076081049),
#  ('number_votes', 0.017354852889873089),
#  ('stars', 0.016248761776057066),
#  ('neighbors_average condition|trail', 0.015791489944980825),
#  ('numReports', 0.015357313658957506),
#  ('Discover Pass', 0.015337883507950765),
#  ('DP01', 0.01462212054127339),
#  ('DP10', 0.013654933480016862),
#  ('PRCP', 0.012743574356182322),
#  ('EMXP', 0.011259608759994894),
#  ('TMAX', 0.0091438168898744319),
#  ('DX70', 0.0078889128024066651),
# ...

# %%
len(X_test.columns)
# Out:
# 140

# %%
len(train_X.columns)
# Out:
# 140

# %%
X_test[train_X.columns]
# Out:
#    date_sin  date_cos  Coast  Dogs not allowed  Established campsites  \
# 0 -0.714876  0.699251      0                 0                      0
#
#    Fall foilage  Good for kids  Lakes  Mountain views  Old growth  ...   TAVG  \
# 0             0              0      1               1           0  ...   49.4
#
#    TMAX  TMIN  TSUN   WDF2   WDF5  WDFG  WSF2  WSF5  WSFG
# 0  57.6  41.1   0.0  150.0  160.0   0.0  35.1  53.9   0.0
#
# [1 rows x 140 columns]

# %%
train_X
# Out:
#        date_sin  date_cos  Coast  Dogs not allowed  Established campsites  \
# 0     -0.714876  0.699251      0                 0                      0
# 1     -0.714876  0.699251      0                 0                      0
# 2     -0.714876  0.699251      0                 0                      0
# 3      0.580611  0.814181      0                 0                      0
# 4      0.580611  0.814181      0                 0                      0
# 5      0.580611  0.814181      0                 0                      0
# 6      0.580611  0.814181      0                 0                      0
# 7      0.580611  0.814181      0                 0                      0
# 8      0.580611  0.814181      0                 0                      0
# 9      0.580611  0.814181      0                 0                      0
# 10     0.580611  0.814181      0                 0                      0
# 11     0.580611  0.814181      0                 0                      0
# ...
