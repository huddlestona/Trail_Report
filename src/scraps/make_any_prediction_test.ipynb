# %%
from make_all_predictions import *

# %%
import pandas as pd

# %%
tp = TrailPred()

# %%
tp.fit()

# %%
tp.models
# Out:
# {'condition|bugs': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False),
#  'condition|road': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False),
#  'condition|snow': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False),
#  'condition|trail': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
# ...

# %%
    hike = 'Mount Rose'
    date = '05/06/18'
    X_test = get_data(hike,date)
# Out:
# /Users/ashley/projects/Trail_Report/src/make_all_predictions.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df[f'neighbors_average {condition}'] = get_new_neighbors(df,condition,hike,date_stamp)
# /Users/ashley/projects/Trail_Report/src/make_all_predictions.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['date'] = date_stamp
# /Users/ashley/projects/Trail_Report/src/make_all_predictions.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X_test_input = X_test[tp.actual_cols].columns

# %%
actual_X_input = tp.X_train.columns

# %%
len(X_test_input),len(actual_X_input),len(X_test.columns)
# Out:
# (140, 140, 140)

# %%
for column in X_test_input:
    if column not in actual_X_input:
        print(column)
    else:
        print('None')
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
    X_all = pd.read_csv('../data/olympics_Xall.csv',sep = '|',lineterminator='\n')
    y_all = pd.read_csv('../data/olympics_yall.csv',sep = '|',lineterminator='\n')

# %%
X_all
# Out:
#        date_sin  date_cos  Coast  Dogs not allowed  Established campsites  \
# 0     -0.714876  0.699251      0                 0                      0
# 1     -0.714876  0.699251      0                 0                      0
# 2     -0.714876  0.699251      0                 0                      0
# 3      0.580611  0.814181      0                 0                      0
# 4      0.580611  0.814181      0                 0                      0
# 5      0.580611  0.814181      0                 0                      0
# 6      0.580611  0.814181      0                 0                      0
# 7      0.580611  0.814181      0                 0                      0
# 8      0.580611  0.814181      0                 0                      0
# 9      0.580611  0.814181      0                 0                      0
# 10     0.580611  0.814181      0                 0                      0
# 11     0.580611  0.814181      0                 0                      0
# ...
