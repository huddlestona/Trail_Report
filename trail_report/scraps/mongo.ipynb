# %%
from pymongo import MongoClient
import pymongo
import math
import pandas as pd
import numpy as np

# %%
    mc = pymongo.MongoClient()

# %%
db = mc['Bigtest']

# %%
small_test = db['Smalltest']

# %%
small_test.insert({name: "Satish", age: 27});
WriteResult({ "nInserted" : 1 })
 
small_test.insert({name: "Kiran", age: 28});
WriteResult({ "nInserted" : 1 })
 
small_test.insert({name: "Satish", age: 27});
WriteResult({ "nInserted" : 1 })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0d67e51a8f57> in <module>()
# ----> 1 small_test.insert({name: "Satish", age: 27});
#       2 WriteResult({ "nInserted" : 1 })
#       3
#       4 small_test.insert({name: "Kiran", age: 28});
#       5 WriteResult({ "nInserted" : 1 })
#
# NameError: name 'name' is not defined

# %%
from pymongo import MongoClient
# Assuming youre running mongod on 'localhost' with port 27017
c = MongoClient('localhost',27017)
c.database_names()
# Out:
# ['admin',
#  'clicks',
#  'config',
#  'lb_tst1',
#  'local',
#  'nyt_dump',
#  'people',
#  'reports',
#  'tweets',
#  'wta',
#  'wta_all']

# %%
db_t = mc['tweets']

# %%
db_t.collection_names()
# Out:
# ['pokemon']

# %%
test = db_t['pokemon']

# %%
test.find_one()
# Out:
# {'_id': ObjectId('5abe6e8bacf3d6de6871e071'),
#  'datetime': datetime.datetime(2018, 3, 30, 10, 6, 19, 592000),
# ...

# %%
test.insert({'_id': ObjectId('5abe6e8bacf3d6de6871e071'),
 'datetime': datetime.datetime(2018, 3, 30, 10, 6, 19, 592000)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8ffbe3a40be7> in <module>()
# ----> 1 test.insert({'_id': ObjectId('5abe6e8bacf3d6de6871e071'),
#       2  'datetime': datetime.datetime(2018, 3, 30, 10, 6, 19, 592000)})
#
# NameError: name 'ObjectId' is not defined

# %%
db.trail_reports.ensureIndex({'Report' : 1}, {unique : true, dropDups : true})
