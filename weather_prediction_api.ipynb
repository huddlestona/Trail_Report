# %%
import pandas as pd

# %%
df = pd.read_json('test_weather.json')

# %%
df
# Out:
#                                         metadata  \
# class                                        NaN
# clds                                         NaN
# day_ind                                      NaN
# dow                                          NaN
# expire_time_gmt                       1526073326
# icon_code                                    NaN
# icon_extd                                    NaN
# imperial                                     NaN
# language                                   en-US
# latitude                                   47.61
# longitude                                -122.33
# obs_qualifier_code                           NaN
# obs_qualifier_severity                       NaN
# obs_time                                     NaN
# obs_time_local                               NaN
# phrase_12char                                NaN
# phrase_22char                                NaN
# phrase_32char                                NaN
# ...

# %%
df['observation'][7]
# Out:
# {'altimeter': 30.21,
#  'ceiling': 3400,
#  'dewpt': 46,
#  'feels_like': 60,
#  'gust': None,
#  'hi': 60,
#  'mslp': 1024.9,
#  'obs_qualifier_100char': None,
#  'obs_qualifier_32char': None,
#  'obs_qualifier_50char': None,
#  'pchange': -0.03,
#  'precip_1hour': 0.0,
#  'precip_24hour': 0.01,
#  'precip_2day': 0.04,
#  'precip_3day': 0.07,
#  'precip_6hour': 0.0,
#  'precip_7day': 0.09,
#  'precip_mtd': 0.09,
#  'precip_ytd': 16.15,
#  'rh': 61,
#  'snow_1hour': 0.0,
#  'snow_24hour': 0.0,
#  'snow_2day': 0.0,
#  'snow_3day': 0.0,
#  'snow_6hour': 0.0,
#  'snow_7day': 0.0,
#  'snow_mtd': 0.0,
#  'snow_season': 1.4,
#  'snow_ytd': 0.2,
#  'temp': 60,
#  'temp_change_24hour': 2,
#  'temp_max_24hour': 60,
#  'temp_min_24hour': 51,
#  'vis': 10.0,
#  'wc': 60,
#  'wspd': 6}
