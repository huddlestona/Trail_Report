# %%
from trail_report.build_model.make_all_predictions import  *
import pandas as pd

# %%
hike = 'Mount Rose'
date = '05/22/18'

# %%
df_init, df_trail, weather, weather_dist = load_databases()

# %%
X_test, Text_X_test = get_data(hike, date,df_init, df_trail, weather, weather_dist)
# Out:
# /Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df, condition, hike, date_stamp)
# /Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['date'] = date_stamp
# /Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['month'] = date_stamp.month
# /Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['year'] = date_stamp.year
# /Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['last_year'] = date_stamp.year - 1
# /Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hike_df['date_sin'], hike_df['date_cos'] = dates_in_circle(hike_df['date'])
# /Users/ashley/projects/Trail_Report/trail_report/build_model/merge_weather.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_hike['closet_station'] = closest_station
# /Users/ashley/projects/Trail_Report/trail_report/build_model/merge_weather.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_hike['station_distance'] = station_distance

# %%
tp = TrailPred()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-170-22c3a2318a9a> in <module>()
# ----> 1 tp = TrailPred()
#
# ~/projects/Trail_Report/trail_report/build_model/make_all_predictions.py in __init__(self)
#     132         self.X_train = pd.read_csv(
#     133             'data/Xall.csv',
# --> 134             sep='|',
#     135             lineterminator='\n')
#     136         self.y_all = pd.read_csv(
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../../data/Xall.csv' does not exist

# %%
tp.fit()

# %%
tp.predict_text(Text_X_test)

# %%
tp.text_pred
# Out:
# {'condition|bugs': [array([160789, 160788,  74322,  74323,  40030])],
#  'condition|road': [array([70215, 70216, 74322, 74323, 93219])],
#  'condition|snow': [array([152633, 152632, 152635, 152634,  57170])],
#  'condition|trail': [array([160788, 160789, 160790,  66059,  66058])]}

# %%
tp.text_pred.items()
# Out:
# dict_items([('condition|snow', [array([152633, 152632, 152635, 152634,  57170])]), ('condition|trail', [array([160788, 160789, 160790,  66059,  66058])]), ('condition|bugs', [array([160789, 160788,  74322,  74323,  40030])]), ('condition|road', [array([70215, 70216, 74322, 74323, 93219])])])

# %%
tp.get_all_text(df_init)

# %%
    snow_text = get_relivant_text(tp.all_text['condition|snow'])
    trail_text = get_relivant_text(tp.all_text['condition|trail'])
    bugs_text= get_relivant_text(tp.all_text['condition|bugs'])
    road_text = get_relivant_text(tp.all_text['condition|road'])

# %%
snow_text
# Out:
# "On 2004-05-30 Reports say: \n \n•  I did not hike beyond the pass, but looking toward Juanita Lake, it appeared that the lake and campground were most likely still under snow\n•  Recommend ice ax\n•  The trail to Boulder Butte likewise was under patchy snow\n•  I encountered patchy snow on the trail at 5900'\n•  However, the snow that was present was not difficult to cross\n•  Contrary to the most recent Trail report by NOCA posted below, the trail was not snow free to the summit nor fully logged out\n\nOn 2004-05-22 Reports say: \n \n• The rain was on and off but not strong enough to hinder a nice walk\n•  There was some mud on the Chybinski trail but overall trail conditions were very good\n\nOn 2010-05-15 Reports say: \n \n• This is just an update about road conditions\n\nOn 2004-05-07 Reports say: \n \n•  I would recommend finding another way across\n\nOn 2004-05-29 Reports say: \n \n•  Looking forward to going back in nicer weather since the views would be pretty spectacular\n• It snowed a little on the way down, but we dodged the rain entirely, and were back at the car around 8:30, exhausted and ready for a chicken strip dinner at Denny's\n•  We had snowshoes and ice axes but didn't need them for the 7 miles of trail we covered\n•  We called it quits around 5700' because it was getting late, we were getting tired, and beyond that point the trail appeared completely snowcovered to the PCT junction\n•  For the next few hours we managed (with some freakish luck) to stay on the trail through long stretches of snow and were rewarded with some nice views of the Sloan Creek valley - though the fog definitely cut down on the views of any peaks\n•  From the river's edge, the trail switchbacks quickly up to the ridgeline, then rolls along until deep snow is encountered around 4000 feet\n•  There is a massive logjam across the river, so no fording needed (or even possible this time of year)\n•  We took a general easterly course and were pleasantly surprised to find the trail (snow free) again atop a narrow ridge\n•  Really nice ridge-walk\n\n"

# %%
trail_text
# Out:
# 'On 2004-05-23 Reports say: \n \n• Started on the trail under clear skies, which quickly changed to a downpour about halfway up the trail, then lightened up a bit\n•  Poles or an ice axe came in handy\n•  Steady snow for the last steep mile or so, providing a great opportunity for some glissading on the way down\n\nOn 2010-05-23 Reports say: \n \n• The trail begins behind Site 15 in the Altair CG which was closed today\n•  Flowers lined the trail most of the way--wild geranium, spring beauty, fringecup, youth-on-age, foamflower, false Solomon\'s seal,larkspur, naked broomrape, orange paintbrush, to name a few\n•  Near the beginning of the trail was a beautiful mushroom we\'re hoping someone can name for us\n• 5 miles the trail crosses Hughes Creek on a sturdy log with a handrail\n\nOn 2010-05-30 Reports say: \n \n•  Take your time because the mud gets slippery in some spots\n•   At the top, beware of cornices and make sure there is rock underneath the snow you are stepping on\n•  We self belayed with our ice axes up\n•  Watch for holes through the snow\n•  Use tree trunks and branches to help pull yourself along\n• So the route follows the overgrown road to the right of the Barclay lake trail\n•   Get up and over that little hill and stay to the left a bit because there is a massive deadly cornice on the right\n\nOn 2004-05-22 Reports say: \n \n•  The trails on this part of Squak are mostly abandoned roads and were in good shape\n•  There was some mud on the Chybinski trail but overall trail conditions were very good\n•  The trail to the view is unmarked but off the parameter loop about 1/8 of a mile from where West Peak meets with the Chybinski trail\n• The rain was on and off but not strong enough to hinder a nice walk\n• Our group, lead by Steve, left the Mountain Side Drive trail head at about 9:30 with the goal of going over the West Peak of Squak and then down the Chybinski trail to loop back to our transportation\n•  The West Peak of Squak is not an easy trail although very short\n\nOn 2010-05-14 Reports say: \n \n•   I continued up the trail to the trail\'s end\n•   I didn\'t see any "unofficial" trail continuing up the basin, but then again everything was snow covered\n•   The only person I ever saw above Lillian Camp was a trail crew cutting out two 6 foot diameter blow downs (thank you trail crew)\n•   The trail is smaller than the main trail, so it feels more intimate, getting closer to the forest\n•   This trail has a different character\n•   Luckily, this is also the end of the official trail\n•   I encountered snow in patches well before the trail end, and at 3,000 feet pretty much the entire ground was snow covered\n• I left the Elwha River at Chicago Camp and headed up the Elwha Basin trail\n•   It\'s not well maintained at all, and has many blowdowns and a couple washouts, where the nearby river has washed away the river bank and trail\n• The Elwha River trail is a thoroughfare for hikers, so it is very well maintained\n•   The trees that line the trail around Hayes River a quite large, beautifully tall douglas firs\n• The ford of the Elwha River was most memorable, not for being a difficult ford (knee deep), but for the cold water (snow melt) and the width of the river at the ford, which left my feet hurt\'n (like brain freeze after eating ice cream too fast)\n\n'

# %%
bugs_text
# Out:
# 'On 2010-05-23 Reports say: \n \n•  No bugs yet though\n\nOn 2004-05-23 Reports say: \n \n• No relevent reports to show at this time!\n\n'

# %%
tp.all_text
# Out:
# {'condition|bugs': [{'2004-05-23': {'No relevent reports to show at this time!'},
#    '2010-05-23': {' No bugs yet though'}}],
#  'condition|road': [{'2004-05-30': {' No snow on the trail at all but still some at the lake basin',
#     ' They looked a little bewildered at how muddy and wet I was'},
#    '2010-05-14': {' I think that the road opens "officially" on 15 June, but the DNR website is singularly unhelpful on this topic',
#     'As hikingwithmybrother reported, the road in is closed at Site 3',
#     'There is no snow at all on the trail and it was sunny and very warm at the lakes'},
#    '2010-05-17': {'  On the return trip I was forced to the side of the road by a monster dump truck that was so huge that it would have required any other vehicle on the road to back up to a pullout',
#     "  That's why the road is closed",
#     '  The road is closed at Site 3, which is 1'},
#    '2010-05-23': {' Quite muddy at times'}}],
#  'condition|snow': [{'2004-05-07': {' I would recommend finding another way across'},
#    '2004-05-22': {' There was some mud on the Chybinski trail but overall trail conditions were very good',
#     'The rain was on and off but not strong enough to hinder a nice walk'},
#    '2004-05-29': {' For the next few hours we managed (with some freakish luck) to stay on the trail through long stretches of snow and were rewarded with some nice views of the Sloan Creek valley - though the fog definitely cut down on the views of any peaks',
#     " From the river's edge, the trail switchbacks quickly up to the ridgeline, then rolls along until deep snow is encountered around 4000 feet",
#     ' Looking forward to going back in nicer weather since the views would be pretty spectacular',
#     ' Really nice ridge-walk',
#     ' There is a massive logjam across the river, so no fording needed (or even possible this time of year)',
#     " We called it quits around 5700' because it was getting late, we were getting tired, and beyond that point the trail appeared completely snowcovered to the PCT junction",
#     " We had snowshoes and ice axes but didn't need them for the 7 miles of trail we covered",
#     ' We took a general easterly course and were pleasantly surprised to find the trail (snow free) again atop a narrow ridge',
#     "It snowed a little on the way down, but we dodged the rain entirely, and were back at the car around 8:30, exhausted and ready for a chicken strip dinner at Denny's"},
#    '2004-05-30': {' Contrary to the most recent Trail report by NOCA posted below, the trail was not snow free to the summit nor fully logged out',
#     ' However, the snow that was present was not difficult to cross',
#     ' I did not hike beyond the pass, but looking toward Juanita Lake, it appeared that the lake and campground were most likely still under snow',
#     " I encountered patchy snow on the trail at 5900'",
#     ' Recommend ice ax',
#     ' The trail to Boulder Butte likewise was under patchy snow'},
#    '2010-05-15': {'This is just an update about road conditions'}}],
#  'condition|trail': [{'2004-05-22': {' The West Peak of Squak is not an easy trail although very short',
#     ' The trail to the view is unmarked but off the parameter loop about 1/8 of a mile from where West Peak meets with the Chybinski trail',
#     ' The trails on this part of Squak are mostly abandoned roads and were in good shape',
#     ' There was some mud on the Chybinski trail but overall trail conditions were very good',
#     'Our group, lead by Steve, left the Mountain Side Drive trail head at about 9:30 with the goal of going over the West Peak of Squak and then down the Chybinski trail to loop back to our transportation',
#     'The rain was on and off but not strong enough to hinder a nice walk'},
#    '2004-05-23': {' Poles or an ice axe came in handy',
#     ' Steady snow for the last steep mile or so, providing a great opportunity for some glissading on the way down',
#     'Started on the trail under clear skies, which quickly changed to a downpour about halfway up the trail, then lightened up a bit'},
#    '2010-05-14': {"  I continued up the trail to the trail's end",
#     '  I didn\'t see any "unofficial" trail continuing up the basin, but then again everything was snow covered',
#     '  I encountered snow in patches well before the trail end, and at 3,000 feet pretty much the entire ground was snow covered',
#     "  It's not well maintained at all, and has many blowdowns and a couple washouts, where the nearby river has washed away the river bank and trail",
#     '  Luckily, this is also the end of the official trail',
#     '  The only person I ever saw above Lillian Camp was a trail crew cutting out two 6 foot diameter blow downs (thank you trail crew)',
#     '  The trail is smaller than the main trail, so it feels more intimate, getting closer to the forest',
#     '  The trees that line the trail around Hayes River a quite large, beautifully tall douglas firs',
#     '  This trail has a different character',
#     'I left the Elwha River at Chicago Camp and headed up the Elwha Basin trail',
#     'The Elwha River trail is a thoroughfare for hikers, so it is very well maintained',
#     "The ford of the Elwha River was most memorable, not for being a difficult ford (knee deep), but for the cold water (snow melt) and the width of the river at the ford, which left my feet hurt'n (like brain freeze after eating ice cream too fast)"},
#    '2010-05-23': {" Flowers lined the trail most of the way--wild geranium, spring beauty, fringecup, youth-on-age, foamflower, false Solomon's seal,larkspur, naked broomrape, orange paintbrush, to name a few",
#     " Near the beginning of the trail was a beautiful mushroom we're hoping someone can name for us",
#     '5 miles the trail crosses Hughes Creek on a sturdy log with a handrail',
#     'The trail begins behind Site 15 in the Altair CG which was closed today'},
#    '2010-05-30': {'  At the top, beware of cornices and make sure there is rock underneath the snow you are stepping on',
#     '  Get up and over that little hill and stay to the left a bit because there is a massive deadly cornice on the right',
#     ' Take your time because the mud gets slippery in some spots',
#     ' Use tree trunks and branches to help pull yourself along',
#     ' Watch for holes through the snow',
#     ' We self belayed with our ice axes up',
#     'So the route follows the overgrown road to the right of the Barclay lake trail'}}]}

# %%
u'•' == u'\u2022'
# Out:
# True

# %%
print (u'\u2022','after the bullit')
# Out:
# • after the bullit

# %%
def get_relivant_text(reports):
    returns = ''
    for group in reports:
        for year,parts in group.items():
            returns += f"On {year} Reports say: \n \n"
            for sent in parts:
                returns += u'\u2022 '
                returns += sent
                returns += '\n'
            returns += '\n'
    return returns

# %%
snow = get_relivant_text(tp.all_text['condition|snow'])

# %%
print(snow)
# Out:
# On 2004-05-30 Reports say:
#
# •  I did not hike beyond the pass, but looking toward Juanita Lake, it appeared that the lake and campground were most likely still under snow
# •  Recommend ice ax
# •  The trail to Boulder Butte likewise was under patchy snow
# •  I encountered patchy snow on the trail at 5900'
# •  However, the snow that was present was not difficult to cross
# •  Contrary to the most recent Trail report by NOCA posted below, the trail was not snow free to the summit nor fully logged out
#
# On 2004-05-22 Reports say:
#
# • The rain was on and off but not strong enough to hinder a nice walk
# •  There was some mud on the Chybinski trail but overall trail conditions were very good
#
# On 2010-05-15 Reports say:
#
# • This is just an update about road conditions
#
# On 2004-05-07 Reports say:
#
# •  I would recommend finding another way across
#
# On 2004-05-29 Reports say:
#
# •  Looking forward to going back in nicer weather since the views would be pretty spectacular
# • It snowed a little on the way down, but we dodged the rain entirely, and were back at the car around 8:30, exhausted and ready for a chicken strip dinner at Denny's
# •  We had snowshoes and ice axes but didn't need them for the 7 miles of trail we covered
# •  We called it quits around 5700' because it was getting late, we were getting tired, and beyond that point the trail appeared completely snowcovered to the PCT junction
# •  For the next few hours we managed (with some freakish luck) to stay on the trail through long stretches of snow and were rewarded with some nice views of the Sloan Creek valley - though the fog definitely cut down on the views of any peaks
# •  From the river's edge, the trail switchbacks quickly up to the ridgeline, then rolls along until deep snow is encountered around 4000 feet
# •  There is a massive logjam across the river, so no fording needed (or even possible this time of year)
# •  We took a general easterly course and were pleasantly surprised to find the trail (snow free) again atop a narrow ridge
# •  Really nice ridge-walk

# %%
for condition, reports in tp.all_text.items():
    print (condition)
    get_relivant_text(reports)
# Out:
# condition|snow
# On 2004-05-30 Reports say:
#
# •  I did not hike beyond the pass, but looking toward Juanita Lake, it appeared that the lake and campground were most likely still under snow
# •  Recommend ice ax
# •  The trail to Boulder Butte likewise was under patchy snow
# •  I encountered patchy snow on the trail at 5900'
# •  However, the snow that was present was not difficult to cross
# •  Contrary to the most recent Trail report by NOCA posted below, the trail was not snow free to the summit nor fully logged out
#
# On 2004-05-22 Reports say:
#
# • The rain was on and off but not strong enough to hinder a nice walk
# •  There was some mud on the Chybinski trail but overall trail conditions were very good
#
# On 2010-05-15 Reports say:
#
# • This is just an update about road conditions
#
# On 2004-05-07 Reports say:
#
# •  I would recommend finding another way across
#
# On 2004-05-29 Reports say:
#
# •  Looking forward to going back in nicer weather since the views would be pretty spectacular
# • It snowed a little on the way down, but we dodged the rain entirely, and were back at the car around 8:30, exhausted and ready for a chicken strip dinner at Denny's
# •  We had snowshoes and ice axes but didn't need them for the 7 miles of trail we covered
# •  We called it quits around 5700' because it was getting late, we were getting tired, and beyond that point the trail appeared completely snowcovered to the PCT junction
# •  For the next few hours we managed (with some freakish luck) to stay on the trail through long stretches of snow and were rewarded with some nice views of the Sloan Creek valley - though the fog definitely cut down on the views of any peaks
# •  From the river's edge, the trail switchbacks quickly up to the ridgeline, then rolls along until deep snow is encountered around 4000 feet
# •  There is a massive logjam across the river, so no fording needed (or even possible this time of year)
# •  We took a general easterly course and were pleasantly surprised to find the trail (snow free) again atop a narrow ridge
# •  Really nice ridge-walk
#
#
# condition|trail
# On 2004-05-23 Reports say:
#
# • Started on the trail under clear skies, which quickly changed to a downpour about halfway up the trail, then lightened up a bit
# •  Poles or an ice axe came in handy
# •  Steady snow for the last steep mile or so, providing a great opportunity for some glissading on the way down
#
# On 2010-05-23 Reports say:
#
# • The trail begins behind Site 15 in the Altair CG which was closed today
# •  Flowers lined the trail most of the way--wild geranium, spring beauty, fringecup, youth-on-age, foamflower, false Solomon's seal,larkspur, naked broomrape, orange paintbrush, to name a few
# •  Near the beginning of the trail was a beautiful mushroom we're hoping someone can name for us
# • 5 miles the trail crosses Hughes Creek on a sturdy log with a handrail
#
# On 2010-05-30 Reports say:
#
# •  Take your time because the mud gets slippery in some spots
# •   At the top, beware of cornices and make sure there is rock underneath the snow you are stepping on
# •  We self belayed with our ice axes up
# •  Watch for holes through the snow
# •  Use tree trunks and branches to help pull yourself along
# • So the route follows the overgrown road to the right of the Barclay lake trail
# •   Get up and over that little hill and stay to the left a bit because there is a massive deadly cornice on the right
#
# On 2004-05-22 Reports say:
#
# •  The trails on this part of Squak are mostly abandoned roads and were in good shape
# •  There was some mud on the Chybinski trail but overall trail conditions were very good
# •  The trail to the view is unmarked but off the parameter loop about 1/8 of a mile from where West Peak meets with the Chybinski trail
# • The rain was on and off but not strong enough to hinder a nice walk
# • Our group, lead by Steve, left the Mountain Side Drive trail head at about 9:30 with the goal of going over the West Peak of Squak and then down the Chybinski trail to loop back to our transportation
# •  The West Peak of Squak is not an easy trail although very short
#
# On 2010-05-14 Reports say:
#
# •   I continued up the trail to the trail's end
# •   I didn't see any "unofficial" trail continuing up the basin, but then again everything was snow covered
# •   The only person I ever saw above Lillian Camp was a trail crew cutting out two 6 foot diameter blow downs (thank you trail crew)
# •   The trail is smaller than the main trail, so it feels more intimate, getting closer to the forest
# •   This trail has a different character
# •   Luckily, this is also the end of the official trail
# •   I encountered snow in patches well before the trail end, and at 3,000 feet pretty much the entire ground was snow covered
# • I left the Elwha River at Chicago Camp and headed up the Elwha Basin trail
# •   It's not well maintained at all, and has many blowdowns and a couple washouts, where the nearby river has washed away the river bank and trail
# • The Elwha River trail is a thoroughfare for hikers, so it is very well maintained
# •   The trees that line the trail around Hayes River a quite large, beautifully tall douglas firs
# • The ford of the Elwha River was most memorable, not for being a difficult ford (knee deep), but for the cold water (snow melt) and the width of the river at the ford, which left my feet hurt'n (like brain freeze after eating ice cream too fast)
#
#
# condition|bugs
# On 2010-05-23 Reports say:
#
# •  No bugs yet though
#
# On 2004-05-23 Reports say:
#
# • No relevent reports to show at this time!
#
#
# condition|road
# On 2010-05-23 Reports say:
#
# •  Quite muddy at times
#
# On 2010-05-17 Reports say:
#
# •   On the return trip I was forced to the side of the road by a monster dump truck that was so huge that it would have required any other vehicle on the road to back up to a pullout
# •   That's why the road is closed
# •   The road is closed at Site 3, which is 1
#
# On 2004-05-30 Reports say:
#
# •  They looked a little bewildered at how muddy and wet I was
# •  No snow on the trail at all but still some at the lake basin
#
# On 2010-05-14 Reports say:
#
# •  I think that the road opens "officially" on 15 June, but the DNR website is singularly unhelpful on this topic
# • As hikingwithmybrother reported, the road in is closed at Site 3
# • There is no snow at all on the trail and it was sunny and very warm at the lakes

# %%
all_text = {}
for condition,indxs in tp.text_pred.items():
    condition_text = []
    for one_rep in indxs:
        print (one_rep)
#         n_text = neigh_text(df_init,one_rep)
#         top = get_all_tops(n_text,condition)
#         condition_text.append(top)
#         all_text[condition] = condition_text
# Out:
# [152633 152632 152635 152634  57170]
# [160788 160789 160790  66059  66058]
# [160789 160788  74322  74323  40030]
# [70215 70216 74322 74323 93219]

# %%
test_size = tp.X_train[tp.X_train.duplicated(keep=False)]

# %%
test_size.count()[0]
# Out:
# 117214

# %%
df_actual = pd.read_csv('data/WTA_all_merged.csv',sep = '|',lineterminator="\n")

# %%
df_actual_X = pd.read_csv('data/Xall.csv',sep = '|',lineterminator="\n")
# Out:
# [autoreload of trail_report.build_model.make_all_predictions failed: Traceback (most recent call last):
#   File "/Users/ashley/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 246, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/ashley/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 369, in superreload
#     module = reload(module)
#   File "/Users/ashley/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/ashley/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/ashley/projects/Trail_Report/trail_report/build_model/make_all_predictions.py", line 2, in <module>
#     from knn_model import prep_neighbors, dates_in_circle, prep_for_knn, make_forest
# ModuleNotFoundError: No module named 'knn_model'
# ]

# %%
    df_clean = df_actual_X.drop(['DX90', 'FZF4', 'FZF3', ' Snoqualmie Pass', 'Waterfalls', 'FZF1', 'FZF8', 'FZF6', 'None', 'Sno-Parks Permit', 'Dogs not allowed', 'FZF0', 'FZF5', 'National Park Pass', 'Discover Pass', 'NaN', ' North Bend Area', ' Salmon La Sac/Teanaway', 'Coast', ' Chinook Pass - Hwy 410', ' SW - Longmire/Paradise', ' Mountain Loop Highway', ' Hood Canal', ' NE - Sunrise/White River', ' Mount Baker Area', ' Stevens Pass - West', ' Stevens Pass - East', ' North Cascades Highway - Hwy 20', " SE - Cayuse Pass/Steven's Canyon", ' Mount Adams Area', ' Leavenworth Area', ' Mount St. Helens', ' Northern Coast', ' White Pass/Cowlitz River Valley', 'WSF5', 'WDF5', 'WDF2', ' Goat Rocks', 'WSF2', 'AWND', ' Yakima', ' Seattle-Tacoma Area', ' Columbia River Gorge - WA', ' Blewett Pass', ' Pacific Coast', ' Methow/Sawtooth', ' Olympia', ' Lewis River Region', ' Tiger Mountain', ' Bellingham Area', ' Entiat Mountains/Lake Chelan', ' Pasayten', " Spokane Area/Coeur d'Alene", ' Dark Divide', ' Columbia River Gorge - OR', 'Wilderness permit. Self-issue at trailhead (no fee)', ' Wenatchee', 'National Monument Fee', 'Discover Pass, Sno-Parks Permit', ' Okanogan Highlands/Kettle River Range', 'National Monument Fee, Sno-Parks Permit', ' Palouse and Blue Mountains', ' Selkirk Range', ' Cougar Mountain', ' Squak Mountain', ' Tri-Cities', ' Kitsap Peninsula', ' Grand Coulee', 'None, Northwest Forest Pass', 'Refuge Entrance Pass', ' Potholes Region', ' Cle Elum Area', ' Whidbey Island', ' San Juan Islands', ' Long Beach Area', ' Vancouver Area', 'Oregon State Parks Day-Use', ' Orcas Island', 'Fall foilage', 'Backcountry camping permit. Register in person at ranger station (no fee)', 'Northwest Forest Pass, Sno-Parks Permit', 'PSUN', 'WDMV'],
                                axis=1)

# %%
tp.X_train.count()[0]
# Out:
# 164939

# %%
df_actual.count()

# %%
df_init
# Out:
#                                        Creator        Date  \
# 0                                         Rajs  2007-06-17
# 1                                    John Deer  2003-12-13
# 2                                 Gary & David  2000-04-19
# 3                                        Ozbun  2000-03-27
# 4                                     D.Baxter  2017-08-19
# 5                              Sir-Hikes-A-Lot  2012-08-05
# 22      I had some trepidation about this hike after r...
# 23      What a great day to do this one. The sky was c...
# 24      A friend and I hiked this one on Sunday and it...
# 25      Gorgeous hike with amazing views the entire wa...
# 26      Went up for a solo early morning snowshoe.  St...
# 27      Had a wonderful first hike up to Snow Lake. St...
# 28      Arrived at around 10am with three others. Ther...
# 29      Snow Lake is a very busy (per the various trai...
# ...                                                   ...
# 112125  Popular trail as expected for a Saturday. Just...
# 112126  Other trip reports are great, but I'll post so...
# 112127  Great day for Lake of the Angels, which is tru...
# 112128  Decided to hike Lake of the Angels today with ...
# 112129    No passes are required to park at the Putvin...
# 112130  The road has some potholes, drive slow. We dri...
# 112131  Left the trailhead at 11:30. Road was in good ...
# 112132  Wow...what a hike! Everything, they write abou...
# 112133  We were hiking by about 8:15 and were the only...
# 112134  I never made it to Lake of Angels because I un...
# 112135  We made it up to Lake of the Angels today. The...
# 112136  Last minute change of plans took me up to Lake...
# 112137  So we opted for Putvin trail today, was normal...
# 112138  tl;dr: a couple blowdowns, creek and snowfield...
# 112139  Amazing Hike! Head Wall is a 5.4 to 5.5 rock c...
# 112140  Inadvertently found this trail after seeing 10...
# 112141  today my newest hiking buddy Harry and I took ...
# 112142  Fine day for an exploration hike on the Putvin...
# 112143  Great views of Mt. Skokomish during most of th...
# 112144  I started this hike very late (noon) which gav...
# 112145  Road to trailhead is covered in multiple feet ...
# 112146  Can't even make it within a couple miles of th...
# 112147  Headed up by Headlamp early for this one!  Lot...
# 112148  Drive up was easy, if you have "business" to t...
# 112149  Beautiful day for a hike! The hike itself was ...
# 112150  We left the car at 9:55am and hiked up the ste...
# 112151  Enjoyed a glorious hike up to Lake of the Ange...
# 112152  This trail was confusing after going through t...
# 112153  To start out I couldn't finish it. I have a fe...
# 112154  A strenuous but beautiful hike. The first part...
#
#                                        Trail  Votes                       _id  \
# 0                       Tiger Mountain Trail    NaN  5b0c80dd6b885c1290ff9f06
# 1                       Tiger Mountain Trail    NaN  5b0c80df6b885c1290ff9f1f
# 2                       Tiger Mountain Trail    NaN  5b0c80e06b885c1290ff9f2d
# 3       Colonel Bob Trail - Colonel Bob Peak    NaN  5b0c80e46b885c1290ff9f56
# 4                              Jackita Ridge    1.0  5b0c80e66b885c1290ff9f5a
# 5                              Jackita Ridge    1.0  5b0c80e86b885c1290ff9f71
# 6                              Jackita Ridge    NaN  5b0c80e86b885c1290ff9f7a
# 7                              Jackita Ridge    NaN  5b0c80e96b885c1290ff9f7f
# 8                              Jackita Ridge    NaN  5b0c80e96b885c1290ff9f80
# 9                              Jackita Ridge    NaN  5b0c80e96b885c1290ff9f81
# 10         Tolmie Peak Lookout - Eunice Lake    NaN  5b0c80f26b885c1290ff9fd1
# 11         Tolmie Peak Lookout - Eunice Lake    NaN  5b0c80f86b885c1290ffa014
# 12         Tolmie Peak Lookout - Eunice Lake    6.0  5b0c80fa6b885c1290ffa026
# 13         Tolmie Peak Lookout - Eunice Lake   10.0  5b0c80fc6b885c1290ffa033
# 14         Tolmie Peak Lookout - Eunice Lake    NaN  5b0c80fc6b885c1290ffa034
# 15         Tolmie Peak Lookout - Eunice Lake    5.0  5b0c81026b885c1290ffa068
# 16         Tolmie Peak Lookout - Eunice Lake    NaN  5b0c81076b885c1290ffa0a0
# 17         Tolmie Peak Lookout - Eunice Lake    NaN  5b0c81086b885c1290ffa0b2
# 18         Tolmie Peak Lookout - Eunice Lake    NaN  5b0
# 15            0    0           9522.459086
# 16            0    0           9522.459086
# 17            0    0           9522.459086
# 18            0    0           9522.459086
# 19            0    0           9522.459086
# 20            0    0           9522.459086
# 21            0    0           9522.459086
# 22            0    0           9522.459086
# 23            0    0           9522.459086
# 24            0    0           9416.179976
# 25            0    0           9416.179976
# 26            0    0           9416.179976
# 27            0    0           9416.179976
# 28            0    0           9416.179976
# 29            0    0           9416.179976
# ...         ...  ...                   ...
# 112125        0    0           9382.214472
# 112126        0    0           9382.214472
# 112127        0    0           9382.214472
# 112128        0    0           9382.214472
# 112129        0    0           9382.214472
# 112130        0    0           9382.214472
# 112131        0    0           9382.214472
# 112132        0    0           9382.214472
# 112133        0    0           9382.214472
# 112134        0    0           9382.214472
# 112135        0    0           9382.214472
# 112136        0    0           9382.214472
# 112137        0    0           9382.214472
# 112138        0    0           9382.214472
# 112139        0    0           9382.214472
# 112140        0    0           9382.214472
# 112141        0    0           9382.214472
# 112142        0    0           9382.214472
# 112143        0    0           9382.214472
# 112144        0    0           9382.214472
# 112145        0    0           9382.214472
# 112146        0    0           9382.214472
# 112147        0    0           9382.214472
# 112148        0    0           9382.214472
# 112149        0    0           9382.214472
# 112150        0    0           9382.214472
# 112151        0    0           9382.214472
# 112152        0    0           9382.214472
# 112153        0    0           9382.214472
# 112154        0    0           9382.214472
#
# [112155 rows x 109 columns]

# %%
df_init.count()[0]
# Out:
# 112153

# %%
indexes = [152633,152632,152635,152634,57170]
df_init.iloc[indexes]['Report']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1793         try:
# -> 1794             return self.obj._take(key, axis=axis, convert=False)
#    1795         except IndexError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _take(self, indices, axis, convert, is_copy)
#    2149                                    axis=self._get_block_manager_axis(axis),
# -> 2150                                    verify=True)
#    2151         result = self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    4254         if convert:
# -> 4255             indexer = maybe_convert_indices(indexer, n)
#    4256
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in maybe_convert_indices(indices, n)
#    2102     if mask.any():
# -> 2103         raise IndexError("indices are out-of-bounds")
#    2104     return indices
#
# IndexError: indices are out-of-bounds
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-cfe270c6d63d> in <module>()
#       1 indexes = [152633,152632,152635,152634,57170]
# ----> 2 df_init.iloc[indexes]['Report']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1817         # a list of integers
#    1818         elif is_list_like_indexer(key):
# -> 1819             return self._get_list_axis(key, axis=axis)
#    1820
#    1821         # a single integer
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1795         except IndexError:
#    1796             # re-raise with different error message
# -> 1797             raise IndexError("positional indexers are out-of-bounds")
#    1798
#    1799     def _getitem_axis(self, key, axis=None):
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# Build make_dataframe to find size difference

# %%
from trail_report.build_model.merge_weather import get_weather_data, merge_weather_trails, get_closest_station
from trail_report.build_model.knn_model import prep_for_knn,prep_neighbors,get_neighbors

# %%
df = pd.read_csv('data/WTA_all_merged.csv', sep = '|',lineterminator='\n')

# %%
df.count()
# Out:
# Creator                                   112153
# Date                                      112155
# Report                                    112152
# Trail                                     112155
# Votes                                      40825
# _id                                       112155
# last_year                                 112155
# month                                     112155
# year                                      112155
# date_sin                                  112155
# date_cos                                  112155
# condition|snow                            112155
# condition|trail                           112155
# condition|bugs                            112155
# condition|road                            112155
# Coast                                     112155
# Dogs not allowed                          112155
# Established campsites                     112155
# Fall foilage                              112155
# Good for kids                             112155
# Lakes                                     112155
# Mountain views                            112155
# Old growth                                112155
# Ridges/passes                             112155
# Rivers                                    112155
# Summits                                   112155
# Waterfalls                                112155
# Wildflowers/Meadows                       112155
# Wildlife                                  112155
# elevation_gain                            100799
#                                            ...
#  North Bend Area                          112155
#  North Cascades Highway - Hwy 20          112155
#  Northern Coast                           112155
#  Okanogan Highlands/Kettle River Range    112155
#  Olympia                                  112155
#  Orcas Island                             112155
#  Pacific Coast                            112155
#  Palouse and Blue Mountains               112155
#  Pasayten                                 112155
#  Potholes Region                          112155
#  SE - Cayuse Pass/Steven's Canyon         112155
#  SW - Longmire/Paradise                   112155
#  Salmon La Sac/Teanaway                   112155
#  San Juan Islands                         112155
#  Seattle-Tacoma Area                      112155
#  Selkirk Range                            112155
#  Snoqualmie Pass                          112155
#  Spokane Area/Coeur d'Alene               112155
#  Squak Mountain                           112155
#  Stevens Pass - East                      112155
#  Stevens Pass - West                      112155
#  Tiger Mountain                           112155
#  Tri-Cities                               112155
#  Vancouver Area                           112155
#  Wenatchee                                112155
#  Whidbey Island                           112155
#  White Pass/Cowlitz River Valley          112155
#  Yakima                                   112155
# NaN                                       112155
# distance_from_median                      110460
# Length: 109, dtype: int64

# %%
def add_knn(df):
    """
    Prep data for knn, runs knn, and adds knn past report values as column in df.
    **Input parameters**
    ------------------------------------------------------------------------------
    df: pandas dataframe of merged trail data and trail reports
    condition: condition being used as y.
    **Output**
    ------------------------------------------------------------------------------
    df_clean: pandas dataframe. Clean results to be merged, with neighbors added.
    """
    df_clean = prep_for_knn(df)
    conditions = ['condition|snow', 'condition|trail','condition|bugs','condition|road']
    for condition in conditions:
        neigh = prep_neighbors(df_clean, condition)
        get_neighbors(neigh,df_clean,condition)
    return df_clean

# %%
df_clean = add_knn(df)

# %%
df_clean.count()[0]
# Out:
# 112155

# %%
def merge_all_files(df_clean):
    """Take clean df and adds weather by nearest station."""
    df_weather,df_weather_dist = get_weather_data()
    get_closest_station(df_clean,df_weather_dist)
    df_merge = merge_weather_trails(df_weather,df_clean)
    return df_merge

# %%
df_merge = merge_all_files(df_clean)

# %%
df_merge
# Out:
#              Date  last_year  month  year  date_sin  date_cos  condition|snow  \
# 0      2007-06-17       2006      6  2007 -0.801153 -0.598460           False
# 1      2007-06-17       2006      6  2007 -0.801153 -0.598460           False
# 2      2007-06-17       2006      6  2007 -0.801153 -0.598460           False
# 3      2003-12-13       2002     12  2003  0.958916 -0.283691           False
# 4      2000-04-19       1999      4  2000  0.580611  0.814181           False
# 5      2000-04-19       1999      4  2000  0.580611  0.814181           False
# 6      2000-03-27       1999      3  2000  0.893997 -0.448074            True
# 7      2000-03-27       1999      3  2000  0.893997 -0.448074            True
# 8      2017-08-19       2016      8  2017  0.945445  0.325781           False
# 9      2012-08-05       2011      8  2012  0.945445  0.325781            True
# 10     2004-08-01       2003      8  2004  0.945445  0.325781           False
# 164937 2016-08-22       2015      8  2016  0.945445  0.325781           False
# 164938 2016-08-17       2015      8  2016  0.945445  0.325781           False
#
#         condition|trail  condition|bugs  condition|road  ...   TMAX  TMIN  \
# 0                  True           False           False  ...    NaN   NaN
# 1                  True           False           False  ...    NaN   NaN
# 2                  True           False           False  ...    NaN   NaN
# 3                 False           False           False  ...    NaN   NaN
# 4                 False           False           False  ...    NaN   NaN
# 5                 False           False           False  ...    NaN   NaN
# 6                 False           False           False  ...    NaN   NaN
# 7                 False           False           False  ...    NaN   NaN
# 8                 False           False           False  ...    NaN   NaN
# 9                  True           False           False  ...    NaN   NaN
# 10                False           False           False  ...    NaN   NaN
# 11                False           False           False  ...    NaN   NaN
# 12                False           False           False  ...    NaN   NaN
# 13                False           False           False  ...    NaN   NaN
# 14                False           False           False  ...    NaN   NaN
# 15                False           False           False  ...    NaN   NaN
# 16                False            True            True  ...   59.1  37.1
# 17                False           False            True  ...   59.1  37.1
# 18                False            True           False  ...   59.1  37.1
# 19                False           False            True  ...   59.1  37.1
# 20                False           False            True  ...   59.1  37.1
# 21                False           False            True  ...   60.6  36.3
# 22                False           False           False  ...   56.5  33.7
# 23                False           False           False  ...   56.5  33.7
# 24                False           False           False  ...   56.5  33.7
# 25                False           False            True  ...   56.5  33.7
# 26                False           False            True  ...   56.5  33.7
# 27                False           False            True  ...   56.5  33.7
# 28                False           False            True  ...   57.1  34.6
# 29                False           False            True  ...   57.1  34.6
# ...                 ...             ...             ...  ...    ...   ...
# 164909            False           False           False  ...    NaN   NaN
# 164910            False            True            True  ...    NaN   NaN
# 164911            False           False           False  ...    NaN   NaN
# 164912             True            True            True  ...    NaN   NaN
# 164913            False            True            True  ...    NaN   NaN
# 164914            False           False            True  ...    NaN   NaN
# 164915            False            True           False  ...    NaN   NaN
# 164916             True           False           False  ...    NaN   NaN
# 164917             True           False           False  ...    NaN   NaN
# 164918             True           False           False  ...    NaN   NaN
# 164919             True           False            True  ...    NaN   NaN
# 164920             True           False           False  ...    NaN   NaN
# 164921             True           False            True  ...    NaN   NaN
# 164922             True           False            True  ...    NaN   NaN
# 164923             True           False            True  ...    NaN   NaN
# 164924            False           False           False  ...    NaN   NaN
# 164925             True           False           False  ...    NaN   NaN
# 164926            False           False           False  ...    NaN   NaN
# 164927             True           False           False  ...    NaN   NaN
# 164928             True           False           False  ...    NaN   NaN
# 164929             True           False            True  ...    NaN   NaN
# 164930             True           False            True  ...    NaN   NaN
# 164931             True           False            True  ...    NaN   NaN
# 164932             True           False           False  ...    NaN   NaN
# 164933            False           False           False  ...    NaN   NaN
# 164934             True           False           False  ...    NaN   NaN
# 164935            False           False           False  ...    NaN   NaN
# 164936            False           False           False  ...    NaN   NaN
# 164937             True           False           False  ...    NaN   NaN
# 164938             True            True            True  ...    NaN   NaN
#
#         TSUN  WDF2  WDF5  WDFG  WDMV  WSF2  WSF5  WSFG
# 0        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 12       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 16       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 17       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 18       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 19       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 20       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 21       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 22       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 24       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 26       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 27       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 28       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 29       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...      ...   ...   ...   ...   ...   ...   ...   ...
# 164909   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164910   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164911   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164912   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164913   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164914   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164915   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164916   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164917   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164918   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164919   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164920   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164921   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164922   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164923   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164924   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164925   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164926   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164927   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164928   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164929   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164930   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164931   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164932   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164933   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164934   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164935   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164936   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164937   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 164938   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [164939 rows x 151 columns]

# %%
df_weather,df_weather_dist = get_weather_data()

# %%
df_weather_clean = df_weather.drop_duplicates(subset=['DATE','name'])

# %%
df_weather.count()[0]
# Out:
# 9984

# %%
df_weather_clean.count()[0]
# Out:
# 5023

# %%
df_clean[['closet_station', 'last_year']]
# Out:
#              closet_station  last_year
# 0       ASOTIN 14 SW, WA US       2006
# 1       ASOTIN 14 SW, WA US       2002
# 2       ASOTIN 14 SW, WA US       1999
# 3       ASOTIN 14 SW, WA US       1999
# 4       ASOTIN 14 SW, WA US       2016
# 5       ASOTIN 14 SW, WA US       2011
# 6       ASOTIN 14 SW, WA US       2003
# 7       ASOTIN 14 SW, WA US       2000
# 8       ASOTIN 14 SW, WA US       2000
# 9       ASOTIN 14 SW, WA US       1999
# 10      BOUNDARY DAM, WA US       2016
# 11      BOUNDARY DAM, WA US       2016
# 12      BOUNDARY DAM, WA US       2016
# 13      BOUNDARY DAM, WA US       2016
# 14      BOUNDARY DAM, WA US       2016
# 15      BOUNDARY DAM, WA US       2015
# 16      BOUNDARY DAM, WA US       2014
# 17      BOUNDARY DAM, WA US       2014
# 18      BOUNDARY DAM, WA US       2013
# 19      BOUNDARY DAM, WA US       2013
# 20      BOUNDARY DAM, WA US       2012
# 21      BOUNDARY DAM, WA US       2012
# 22      BOUNDARY DAM, WA US       2012
# 23      BOUNDARY DAM, WA US       1999
# 24      BOUNDARY DAM, WA US       2016
# 25      BOUNDARY DAM, WA US       2016
# 26      BOUNDARY DAM, WA US       2016
# 27      BOUNDARY DAM, WA US       2015
# 28      BOUNDARY DAM, WA US       2015
# 29      BOUNDARY DAM, WA US       2015
# ...                     ...        ...
# 112125  ASOTIN 14 SW, WA US       2016
# 112126  ASOTIN 14 SW, WA US       2016
# 112127  ASOTIN 14 SW, WA US       2016
# 112128  ASOTIN 14 SW, WA US       2016
# 112129  ASOTIN 14 SW, WA US       2016
# 112130  ASOTIN 14 SW, WA US       2016
# 112131  ASOTIN 14 SW, WA US       2016
# 112132  ASOTIN 14 SW, WA US       2016
# 112133  ASOTIN 14 SW, WA US       2016
# 112134  ASOTIN 14 SW, WA US       2016
# 112135  ASOTIN 14 SW, WA US       2016
# 112136  ASOTIN 14 SW, WA US       2016
# 112137  ASOTIN 14 SW, WA US       2016
# 112138  ASOTIN 14 SW, WA US       2016
# 112139  ASOTIN 14 SW, WA US       2016
# 112140  ASOTIN 14 SW, WA US       2016
# 112141  ASOTIN 14 SW, WA US       2016
# 112142  ASOTIN 14 SW, WA US       2016
# 112143  ASOTIN 14 SW, WA US       2016
# 112144  ASOTIN 14 SW, WA US       2016
# 112145  ASOTIN 14 SW, WA US       2016
# 112146  ASOTIN 14 SW, WA US       2015
# 112147  ASOTIN 14 SW, WA US       2015
# 112148  ASOTIN 14 SW, WA US       2015
# 112149  ASOTIN 14 SW, WA US       2015
# 112150  ASOTIN 14 SW, WA US       2015
# 112151  ASOTIN 14 SW, WA US       2015
# 112152  ASOTIN 14 SW, WA US       2015
# 112153  ASOTIN 14 SW, WA US       2015
# 112154  ASOTIN 14 SW, WA US       2015
#
# [112155 rows x 2 columns]

# %%
df_weather[['DATE','name']]
# Out:
#        DATE                               name
# 0      1997                 STARTUP 1 E, WA US
# 1      1998                 STARTUP 1 E, WA US
# 2      1997                   OLGA 2 SE, WA US
# 3      1998                   OLGA 2 SE, WA US
# 4      1997                    ROSS DAM, WA US
# 5      1998                    ROSS DAM, WA US
# 6      1997                     ROSALIA, WA US
# 7      1998                     ROSALIA, WA US
# 8      1997              MOSES MOUNTAIN, WA US
# 9      1998              MOSES MOUNTAIN, WA US
# 10     1997                   FISH LAKE, WA US
# 11     1998                   FISH LAKE, WA US
# 12     1997                     PROSSER, WA US
# 13     1997          MOUNT VERNON 3 WNW, WA US
# 14     1998          MOUNT VERNON 3 WNW, WA US
# 15     1997             RITZVILLE 1 SSE, WA US
# 16     1998             RITZVILLE 1 SSE, WA US
# 17     1997                    COLVILLE, WA US
# 18     1998                    COLVILLE, WA US
# 19     1997                      WILBUR, WA US
# 20     1998                      WILBUR, WA US
# 21     1997                  QUINCY 1 S, WA US
# 22     1998                  QUINCY 1 S, WA US
# 23     1997                    PARADISE, WA US
# 24     1998                    PARADISE, WA US
# 25     1997                    LACROSSE, WA US
# 26     1998                    LACROSSE, WA US
# 27     1997                    CLE ELUM, WA US
# 28     1998                    CLE ELUM, WA US
# 29     1997                      SMYRNA, WA US
# ...     ...                                ...
# 9974   1998                CHIMACUM 4 S, WA US
# 9975   1997                  ELLENSBURG, WA US
# 9976   1998                  ELLENSBURG, WA US
# 9977   1998                PULLMAN 2 NW, WA US
# 9978   1997              WINTHROP 1 WSW, WA US
# 9979   1998              WINTHROP 1 WSW, WA US
# 9980   1997                 WELLS CREEK, WA US
# 9981   1998                 WELLS CREEK, WA US
# 9982   1997                  WATERVILLE, WA US
# 9983   1997         SEATTLE PORTAGE BAY, WA US
# 9984   1997                  RAINY PASS, WA US
# 9985   1998                  RAINY PASS, WA US
# 9986   1998                MINERS RIDGE, WA US
# 9987   1997             COULEE DAM 1 SW, WA US
# 9988   1997                      WAPATO, WA US
# 9989   1997               SEDRO WOOLLEY, WA US
# 9990   1997  HUMPTULIPS SALMON HATCHERY, WA US
# 9991   1997                       PLAIN, WA US
# 9992   1998                       PLAIN, WA US
# 9993   1998        RAINIER PARADISE RNG, WA US
# 9994   1998             UPPER BAKER DAM, WA US
# 9995   1997                  COUGAR 6 E, WA US
# 9996   1998                  COUGAR 6 E, WA US
# 9997   1997                  METHOW 2 S, WA US
# 9998   1998                  METHOW 2 S, WA US
# 9999   1997            CHIEF JOSEPH DAM, WA US
# 10000  1998            CHIEF JOSEPH DAM, WA US
# 10001  1997             MOXEE CITY 10 E, WA US
# 10002  1997          RAINER OHANAPECOSH, WA US
# 10003  1998          RAINER OHANAPECOSH, WA US
#
# [9984 rows x 2 columns]

# %%
get_closest_station(df_clean,df_weather_dist)

# %%
    df_trail_year = pd.merge(
        df_clean, df_weather_clean, how='left', left_on=[
            'closet_station', 'last_year'], right_on=[
            'name', 'DATE'])

# %%
df_trail_year.count()
# Out:
# Date                     112155
# last_year                112155
# month                    112155
# year                     112155
# date_sin                 112155
# date_cos                 112155
# condition|snow           112155
# condition|trail          112155
# condition|bugs           112155
# condition|road           112155
# Coast                    112155
# Dogs not allowed         112155
# Established campsites    112155
# Fall foilage             112155
# Good for kids            112155
# Lakes                    112155
# Mountain views           112155
# Old growth               112155
# Ridges/passes            112155
# Rivers                   112155
# Summits                  112155
# Waterfalls               112155
# Wildflowers/Meadows      112155
# Wildlife                 112155
# elevation_gain           112155
# highest_point            112155
# lat                      112155
# long                     112155
# numReports               112155
# number_votes             112155
#                           ...
# EMSN                      20959
# EMXP                      51431
# EMXT                      45494
# FZF0                      43428
# FZF1                      43346
# FZF2                      42372
# FZF3                      39240
# FZF4                      35415
# FZF5                      43428
# FZF6                      42777
# FZF7                      42153
# FZF8                      39182
# FZF9                      37959
# HDSD                      42223
# HTDD                      42223
# PRCP                      52616
# PSUN                          0
# SNOW                      20959
# TAVG                      43428
# TMAX                      45494
# TMIN                      43428
# TSUN                          0
# WDF2                       2719
# WDF5                       2719
# WDFG                          0
# WDMV                          0
# WSF2                       2719
# WSF5                       2719
# WSFG                          0
# name                      59935
# Length: 153, dtype: int64

# %%
df_init[df_init['Date'] == '2010-05-14']
# Out:
#                 Creator        Date  \
# 558     letthewookiewin  2010-05-14
# 9864               Norm  2010-05-14
# 13433    Wander_the_pnw  2010-05-14
# 15660        Lone Cedar  2010-05-14
# 32054         whitebark  2010-05-14
# 32619        OutdoorDan  2010-05-14
# 43916           MikeeMo  2010-05-14
# 45631        toadlicker  2010-05-14
# 63308           terpene  2010-05-14
# 67535             ejain  2010-05-14
# 69387             Aspen  2010-05-14
# 76090       Hikingqueen  2010-05-14
# 83361         john deer  2010-05-14
# 104426            Tomas  2010-05-14
# 106170         Contrail  2010-05-14
# 107967          ABhiker  2010-05-14
#
#                                                    Report  \
# 558     We hit the trailhead at around 11:15.  The hik...
# 9864    Seasonal trip to raise the shutters.  Road is ...
# 13433   Conditions could not of been better. The weath...
# 15660   Flowers in bloom with many plants, including h...
# 32054   We enjoyed glorious hiking conditions on the G...
# 32619   A wonderful warm sunny day for a hike.  Wasn't...
# 43916   Twas a beautiful day for a jaunt up the Teanaw...
# 45631   The Elwha River trail is a thoroughfare for hi...
# 63308   As hikingwithmybrother reported, the road in i...
# 67535   Got started sometime before noon. The parking ...
# 69387   What a great day for a hike! The first mile or...
# 76090   I've read about this trail for years, finally ...
# 83361   This trail is accessed at the very end of the ...
# 104426  Set out on Little Si trail with destination of...
# 106170  This hike was challenging to say the least!  F...
# 107967  Great day for a nice hike to the top of a moun...
#
#                                 Trail  Votes                       _id  \
# 558                      Barclay Lake    NaN  5b0c86da6b885c1290ffdd46
# 9864                   Mount Pilchuck    NaN  5b0c92536b885c12900054ab
# 13433                      Twin Falls    NaN  5b0c94416b885c1290006757
# 15660             Umtanum Ridge Crest    NaN  5b0c95a26b885c1290007439
# 32054                       Goat Lake    NaN  5b0ca0436b885c129000d261
# 32619                   Boulder River    NaN  5b0ca0966b885c129000d524
# 43916      Johnson Creek - Medra Pass    NaN  5b0ca8ff6b885c12900117e4
# 45631   Elwha River and Lillian River    NaN  5b0caa276b885c12900121f0
# 63308                   Greider Lakes    NaN  5b0cb68c6b885c12900183ed
# 67535               Rattlesnake Ledge    NaN  5b0cb86c6b885c13fbc7315f
# 69387                        Mount Si    NaN  5b0cb92b6b885c13fbc7376c
# 76090                    Dog Mountain    NaN  5b0cbc5b6b885c13fbc74e72
# 83361                    Quartz Creek    NaN  5b0cc15c6b885c129001c913
# 104426           Mount Si - Old Trail    NaN  5b1065a16b885c2c212370c4
# 106170       Mailbox Peak - Old Trail    NaN  5b1066916b885c2c21237b5d
# 107967                      East Peak    NaN  5b1067866b885c2c212386a0
#
#         last_year  month  year  date_sin          ...           \
# 558          2009      5  2010 -0.714876          ...
# 9864         2009      5  2010 -0.714876          ...
# 13433        2009      5  2010 -0.714876          ...
# 15660        2009      5  2010 -0.714876          ...
# 32054        2009      5  2010 -0.714876          ...
# 32619        2009      5  2010 -0.714876          ...
# 43916        2009      5  2010 -0.714876          ...
# 45631        2009      5  2010 -0.714876          ...
# 63308        2009      5  2010 -0.714876          ...
# 67535        2009      5  2010 -0.714876          ...
# 69387        2009      5  2010 -0.714876          ...
# 76090        2009      5  2010 -0.714876          ...
# 83361        2009      5  2010 -0.714876          ...
# 104426       2009      5  2010 -0.714876          ...
# 106170       2009      5  2010 -0.714876          ...
# 107967       2009      5  2010 -0.714876          ...
#
#          Stevens Pass - West   Tiger Mountain   Tri-Cities   Vancouver Area  \
# 558                        1                0            0                0
# 9864                       0                0            0                0
# 13433                      0                0            0                0
# 15660                      0                0            0                0
# 32054                      0                0            0                0
# 32619                      0                0            0                0
# 43916                      0                0            0                0
# 45631                      0                0            0                0
# 63308                      1                0            0                0
# 67535                      0                0            0                0
# 69387                      0                0            0                0
# 76090                      0                0            0                0
# 83361                      1                0            0                0
# 104426                     0                0            0                0
# 106170                     0                0            0                0
# 107967                     0                0            0                0
#
#          Wenatchee   Whidbey Island   White Pass/Cowlitz River Valley  \
# 558              0                0                                 0
# 9864             0                0                                 0
# 13433            0                0                                 0
# 15660            0                0                                 0
# 32054            0                0                                 0
# 32619            0                0                                 0
# 43916            0                0                                 0
# 45631            0                0                                 0
# 63308            0                0                                 0
# 67535            0                0                                 0
# 69387            0                0                                 0
# 76090            0                0                                 0
# 83361            0                0                                 0
# 104426           0                0                                 0
# 106170           0                0                                 0
# 107967           0                0                                 0
#
#          Yakima  NaN  distance_from_median
# 558           0    0           9339.045364
# 9864          0    0           9277.643059
# 13433         0    0           9409.320884
# 15660         1    0           9525.814404
# 32054         0    0           9275.875208
# 32619         0    0           9257.704571
# 43916         0    0           9418.231455
# 45631         0    0           9315.347607
# 63308         0    0           9320.006776
# 67535         0    0           9411.131673
# 69387         0    0           9404.695496
# 76090         0    0           9778.305887
# 83361         0    0           9322.762577
# 104426        0    0           9408.964927
# 106170        0    0           9406.506237
# 107967        0    1           9398.088060
#
# [16 rows x 109 columns]
